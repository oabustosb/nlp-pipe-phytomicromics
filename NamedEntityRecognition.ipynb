# %% [markdown]
# ## Import and Data Load

# %%
import pandas as pd
import numpy as np
import json
import requests
import time

# %% [markdown]
# ## BERT - Pretrained models

# %%
with_pmc = pd.read_excel("DatasetPositivo.xlsx")
with_pmc = with_pmc[with_pmc.Abstract != ""]
with_pmc

# %%
titles = with_pmc['Title'].tolist()
abstracts = with_pmc['Abstract'].tolist()

# %%
id_list = with_pmc['PMID'].values
#real_list = with_pmc['Target'].values

# %%
from unidecode import unidecode

def text_process(text, type_='list'):
    preproc = text.lower()
    preproc = unidecode(preproc)
    if type_=='list':
        preproc = preproc.split(',')
    return preproc

abstracts = [text_process(text, type_='notlist') for text in with_pmc.Abstract.tolist()]
with_pmc['Abstract_preproc'] = abstracts

# %%
import re

def compare_rows(text, textlist):
    compare = False
    if text in textlist or text+'s' in textlist:
        compare = True
    elif '(' in text:
        newt = re.sub(r'\([^)]*\)', '', text)
        if newt in textlist or newt+'s' in textlist:
            compare = True
    return compare

# %%
from transformers import pipeline
from transformers import AutoTokenizer

base_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def hugging_model_process(model_name, tokenizer, text, offset=0):

    token = model_name if tokenizer else base_tokenizer
    ner_model = pipeline(task="ner", model=model_name, tokenizer=token)
    model_res = ner_model(text, aggregation_strategy="first")

    array_res = []
    for dic in model_res:
        annot_type = dic['entity_group']
        if annot_type.lower() in ['chemical','bio','b']:
            annot_text = dic['word']
            annot_loc = {'start': dic['start'] + offset, 'end': dic['end'] + offset}
            res = {'text': annot_text, 'location': annot_loc}
            array_res.append(res)
    return array_res

# %%
hf_models = ["raynardj/ner-chemical-bionlp-bc5cdr-pubmed",
             "alvaroalon2/biobert_chemical_ner",
             "aitslab/biobert_huner_chemical_v1",
             "pruas/BENT-PubMedBERT-NER-Chemical"]

# %% [markdown]
# #### Raynard

# %%
raylist = []
for i, text in enumerate(abstracts):
    offset = len(titles[i])
    raychemres = hugging_model_process(hf_models[0], True, text, offset)
    rayres = {'id': id_list[i], 'chemical': raychemres}
    raylist.append(rayres)

# %%
ray_list = []

for id in raylist:
    chemlist = []
    for chem in id['chemical']:
        chemlist.append(chem['text'].lower()[1:])
    ray_list.append(chemlist)

print(len(ray_list))

# %%
len(ray_list)

# %%
with_pmc['Raynardj'] = ray_list

# %% [markdown]
# #### AlonBioBert

# %%
alonlist = []
for i, text in enumerate(abstracts):
    offset = len(titles[i])
    alonchemres = hugging_model_process(hf_models[1], True, text, offset)
    alonres = {'id': id_list[i], 'chemical': alonchemres}
    alonlist.append(alonres)

# %%
alon_list = []

for id in alonlist:
    chemlist = []
    for chem in id['chemical']:
        chemlist.append(chem['text'].lower())
    alon_list.append(chemlist)

print(len(alon_list))

# %%
len(alon_list)

# %%
with_pmc['AlvaroAlon'] = alon_list

# %% [markdown]
# #### AitsLab

# %%
aitslist = []
for i, text in enumerate(abstracts):
    offset = len(titles[i])
    aitschemres = hugging_model_process(hf_models[2], False, text, offset)
    aitsres = {'id': id_list[i], 'chemical': aitschemres}
    aitslist.append(aitsres)

# %%
aits_list = []

for id in aitslist:
    chemlist = []
    for chem in id['chemical']:
        chemlist.append(chem['text'].lower())
    aits_list.append(chemlist)

print(len(aits_list))

# %%
with_pmc['AitsLab'] = aits_list

# %% [markdown]
# #### Pruas

# %%
ner_model = pipeline(task="ner", model=hf_models[3], tokenizer=base_tokenizer)
model_res = ner_model(abstracts[0], aggregation_strategy="first")
print(model_res)

# %%
pruaslist = []
for i, text in enumerate(abstracts):
    offset = len(titles[i])
    try:
        pruaschemres = hugging_model_process(hf_models[3], True, text, offset)
        pruasres = {'id': id_list[i], 'chemical': pruaschemres}
    except:
        pruasres = {'id': id_list[i], 'chemical': ''}
    pruaslist.append(pruasres)

# %%
pruaslist[0]

# %%
pruas_list = []

for id in pruaslist:
    chemlist = []
    for chem in id['chemical']:
        chemlist.append(chem['text'].lower())
    pruas_list.append(chemlist)

print(len(pruas_list))

# %%
with_pmc['Pruas'] = pruas_list

# %% [markdown]
# ## Export

# %%
reduce = lambda l: np.unique(l)

with_pmc['Raynardj'] = with_pmc['Raynardj'].apply(reduce)
with_pmc['AlvaroAlon'] = with_pmc['AlvaroAlon'].apply(reduce)
with_pmc['AitsLab'] = with_pmc['AitsLab'].apply(reduce)
with_pmc['Pruas'] = with_pmc['Pruas'].apply(reduce)

# %%
with_pmc

# %%
def process_response(response):
    M = []
    if len(response) == 0:
        return np.array([])

    for elem in response:
        transf = re.sub(r",|\.",'',elem)
        transf = re.sub(r"'",'',transf)
        transf = re.sub(r"\s\-\s",'-',transf)
        transf = re.sub(r"\s?\(\s?",'(',transf)
        transf = re.sub(r"\s?\)\s?",')',transf)
        transf = re.sub(r"\s{2,}",' ',transf)
        M.append(transf)
    return np.unique(M)

# %%
with_pmc['Raynardj'] = with_pmc['Raynardj'].apply(process_response)
with_pmc['AlvaroAlon'] = with_pmc['AlvaroAlon'].apply(process_response)
with_pmc['AitsLab'] = with_pmc['AitsLab'].apply(process_response)
with_pmc['Pruas'] = with_pmc['Pruas'].apply(process_response)

# %%
all_res = [ np.concatenate((with_pmc['Raynardj'][i].astype(list),
                          with_pmc['AlvaroAlon'][i].astype(list),
                          with_pmc['AitsLab'][i].astype(list),
                          with_pmc['Pruas'][i].astype(list))) for i in list(with_pmc.index)]

one_res = [np.unique(res) for res in all_res]
with_pmc['Combined words 1/4'] = one_res
# Out:
# <ipython-input-60-0d19bf7349a5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   with_pmc['Combined words 1/4'] = one_res

# %%
with_pmc
# Out:
#         PMC_ID      PMID                                              Title  \
# 1      4790266  27029317  Pipeline of Known Chemical Classes of Antibiot...
# 31     3318344  22232283  In vitro potential of equine DEFA1 and eCATH1 ...
# 34     4249419  25199778  Effective control of Salmonella infections by ...
# 35     4249419  25199778  Effective control of Salmonella infections by ...
# 36     4249444  25199777  In vitro potential of Lycosin-I as an alternat...
# ...        ...       ...                                                ...
# 2716   3667366  23741637  Rhodomycin analogues from Streptomyces purpura...
# 2725   4102832  23931281  Salinomycin: a novel anti-cancer agent with kn...
# 2746  10187937  37192172  Streptothricin F is a bactericidal antibiotic ...
# 2775   8068249  33917912  The Nonribosomal Peptide Valinomycin: From Dis...
# 2778   2765823  19105177  Investigations into viomycin biosynthesis by u...
#
#                                                Abstract  \
# 1     Many approaches are used to discover new antib...
# 31    Rhodococcus equi, the causal agent of rhodococ...
# 34    We successfully produced two human β-defensins...
# 35    We successfully produced two human β-defensins...
# 36    The resistance of multidrug-resistant Acinetob...
# ...                                                 ...
# 2716  During a screening program for bioactive natur...
# 2725  Salinomycin, traditionally used as an anti-coc...
# 2746  The streptothricin natural product mixture (al...
# 2775  Valinomycin is a nonribosomal peptide that was...
# 2778  Viomycin and capreomycin are members of the tu...
#
#                                                  Target  \
# 1                              [fy-901, aminoglycoside]
# 31                      [ecath1, antimicrobial peptide]
# 34                       [hbd-1, antimicrobial peptide]
# 35                       [hbd-2, antimicrobial peptide]
# 36                   [lycosin 1, antimicrobial peptide]
# ...                                                 ...
# 2716                        [rhodomycin, anthracycline]
# 2725    [salinomycin, polyether antibiotic (ionophore)]
# 2746                   [streptothricin, streptothricin]
# 2775  [valinomycin, antimicrobial peptide (cyclodode...
# 2778  [viomycin, celiomycin, florimycin, tuberactino...
#
#                                        Abstract_preproc  \
# 1     many approaches are used to discover new antib...
# 31    rhodococcus equi, the causal agent of rhodococ...
# 34    we successfully produced two human b-defensins...
# 35    we successfully produced two human b-defensins...
# 36    the resistance of multidrug-resistant acinetob...
# ...                                                 ...
# 2716  during a screening program for bioactive natur...
# 2725  salinomycin, traditionally used as an anti-coc...
# 2746  the streptothricin natural product mixture (al...
# 2775  valinomycin is a nonribosomal peptide that was...
# 2778  viomycin and capreomycin are members of the tu...
#
#                                                Raynardj  \
# 1     [lipopeptides, quinolones aminoglycosides macr...
# 31                                   [ecath1, rifampin]
# 34                                                   []
# 35                                                   []
# 36          [ca(2+)), d-lycosin-i, l-, lycosin-i, salt]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, aglycones, ethyl acetate, o...
# 2725                                      [salinomycin]
# 2746  [carbapenem-resistant, guanine, gulosamine, ly...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino, beta-lysine, capreomycin, carb...
#
#                                              AlvaroAlon  \
# 1     [aminoglycosides, beta-lactams, lipoglycopepti...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36     [ca(2 +), l-and d-lycosin-i, lycosin-i, mg(2 +)]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [-, - f, carbapenem, guanine, gulosamine, hydr...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino acid, beta-amino, beta-lysine, ...
#
#                                                 AitsLab  \
# 1     [aminoglycosides, beta-lactams, macrolides, ox...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36     [ca(2 +), l-and d-lycosin-i, lycosin-i, mg(2 +)]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [carbamoylated gulosamine, guanine, hydrogen, ...
# 2775                                      [valinomycin]
# 2778  [acetyl, acetylated viomycin, amino acid, beta...
#
#                                                   Pruas  \
# 1     [aminoglycosides, beta, cyclic, lipoglycopepti...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36                                 [ca, l, lycosin, mg]
# ...                                                 ...
# 2716         [a2, ethyl, obelmycin, rhodomycin, sugars]
# 2725                                      [salinomycin]
# 2746  [carbamoylated, carbapenem, guanine, hydrogen,...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino, beta, capreomycin, carbamoyl, ...
#
#                                      Combined words 1/4
# 1     [aminoglycosides, beta, beta-lactams, cyclic, ...
# 31                                   [ecath1, rifampin]
# 34                                                   []
# 35                                                   []
# 36    [ca, ca(2 +), ca(2+)), d-lycosin-i, l, l-, l-a...
# ...                                                 ...
# 2716  [a2, a2-rhodomycin ii, aglycones, ethyl, ethyl...
# 2725                                      [salinomycin]
# 2746  [-, - f, carbamoylated, carbamoylated gulosami...
# 2775                                      [valinomycin]
# 2778  [acetyl, acetylated viomycin, amino, amino aci...
#
# [122 rows x 11 columns]

# %%
all_res = [np.unique(res, return_counts=True) for res in all_res]
all_res
# Out:
# [(array(['aminoglycosides', 'beta', 'beta-lactams', 'cyclic',
#          'lipoglycopeptides', 'lipopeptides', 'macrolides',
#          'oxazolidinones', 'pleuromutilins', 'polymyxins', 'quinolones',
#          'quinolones aminoglycosides macrolides oxazolidinones tetracyclines pleuromutilins beta-lactams lipoglycopeptides polymyxins',
#          'r', 'tetracyclines'], dtype=object),
#   array([3, 1, 2, 1, 2, 1, 3, 3, 3, 3, 3, 1, 1, 3])),
#  (array(['ecath1', 'rifampin'], dtype=object), array([1, 4])),
#  (array([], dtype=object), array([], dtype=int64)),
#  (array([], dtype=object), array([], dtype=int64)),
#  (array(['ca', 'ca(2 +)', 'ca(2+))', 'd-lycosin-i', 'l', 'l-',
#          'l-and d-lycosin-i', 'lycosin', 'lycosin-i', 'mg', 'mg(2 +)',
#          'salt'], dtype=object),
#   array([1, 2, 1, 1, 1, 1, 2, 1, 3, 1, 2, 1])),
#  (array(['calcium', 'carbohydrate', 'd', 'd-alanyl -', 'd-alanyl-l-alanine',
#          'l-alanine', 'nacl'], dtype=object),
#   array([4, 3, 1, 1, 2, 1, 4])),
#  (array(['b', 'b-lactams', 'c', 'macrolides', 'n'], dtype=object),
#   array([1, 3, 2, 3, 2])),
#  (array(['avibactam', 'b', 'b-lactam', 'ceftazidime',
#          'ceftazidime-avibactam', 'ceftolozane', 'ceftolozane-tazobactam',
#          'tazobactam'], dtype=object),
#   array([3, 1, 2, 3, 1, 3, 1, 3])),
#  (array(['dsta4637s', 'fluoroquinolone', 'rifamycin', 'rifamycins', 'td',
#          'td-1792', 'tnp', 'tnp-2092', 'vancomycin'], dtype=object),
#   array([3, 4, 4, 4, 1, 2, 1, 1, 4])),
#  (array(['honey', 'honey surgihoneyro', 'hydrogen', 'hydrogen peroxide',
#          'polycaprolactone', 'polycaprolactone-honey', 'surgihoneyro',
#          'surgihoneyro-containing'], dtype=object),
#   array([1, 1, 1, 3, 4, 1, 1, 1])),
#  (array(['gpi0363', 'gpi0363-resistant', 'methicillin',
#          'methicillin-resistant', 'spiro', 'spiro-heterocyclic',
#          'synthetic'], dtype=object),
#   array([3, 1, 3, 1, 1, 1, 1])),
#  (array(['6076', 'adej', 'antibiotics', 'eravacycline', 'fluorocycline',
#          'tetracycline', 'tetracycline-based', 'tp', 'tp-6076'],
#         dtype=object),
#   array([1, 1, 1, 4, 4, 4, 1, 3, 3])),
#  (array(['aminomethyl', 'aminomethyl tetrahydrofuranyl',
#          'aminomethyl tetrahydrofuranyl(thf)-1 beta-methylcarbapenems',
#          'beta-methylcarbapenems', 'biapenem', 'biapenem imipenem',
#          'carbapenems', 'cl', 'cl 188 624', 'cl 188624',
#          'cl 188624 cl 190294', 'cl 190 294', 'cl 190294', 'cl 191 121',
#          'cl 191121', 'imipenem', 'meropenem', 'methicillin',
#          'methicillin-susceptible', 'thf', 'thf carbapenems'], dtype=object),
#   array([1, 2, 1, 2, 4, 1, 4, 1, 2, 1, 1, 2, 1, 2, 1, 4, 4, 3, 1, 2, 4])),
#  (array(['aminomethyl', 'aminomethyl tetrahydrofuranyl',
#          'aminomethyl tetrahydrofuranyl(thf)-1 beta-methylcarbapenems',
#          'beta-methylcarbapenems', 'biapenem', 'biapenem imipenem',
#          'carbapenems', 'cl', 'cl 188 624', 'cl 188624',
#          'cl 188624 cl 190294', 'cl 190 294', 'cl 190294', 'cl 191 121',
#          'cl 191121', 'imipenem', 'meropenem', 'methicillin',
#          'methicillin-susceptible', 'thf', 'thf carbapenems'], dtype=object),
#   array([1, 2, 1, 2, 4, 1, 4, 1, 2, 1, 1, 2, 1, 2, 1, 4, 4, 3, 1, 2, 4])),
#  (array(['beta', 'beta-lactam', 'c-7', 'cephalosporin', 'cephalothin',
#          'cephalothin nb2001', 'enoyl', 'nb2001', 'nb2001 nb2030', 'nb2030',
#          'penicillin', 'penicillin-binding', 'tetrazole', 'thienyl',
#          'triclosan'], dtype=object),
#   array([1, 2, 1, 4, 4, 1, 2, 4, 1, 4, 2, 1, 4, 4, 4])),
#  (array(['ar', 'ar-709', 'diaminopyrimidine'], dtype=object),
#   array([1, 3, 4])),
#  (array(['8', '8-methoxy fluoroquinolone', 'ciprofloxacin', 'dc', 'dc-159a',
#          'fluoroquinolones', 'garenoxacin', 'levofloxacin',
#          'levofloxacin ciprofloxacin', 'levofloxacin-intermediate',
#          'methicillin', 'methicillin-resistant', 'moxifloxacin',
#          'quinolone', 'quinolone-', 'quinolone-resistant', 'quinolones'],
#         dtype=object),
#   array([1, 3, 3, 1, 3, 4, 2, 4, 1, 1, 3, 1, 4, 3, 1, 1, 4])),
#  (array(['chp', 'chp-105', 'levofloxacin', 'quinolone'], dtype=object),
#   array([1, 3, 4, 4])),
#  (array(['amikacin', 'aminopyrrolidine',
#          'aminopyrrolidine-substituted fluorocyclopropyl naphthyridine quinolone',
#          'ampicillin', 'aztreonam', 'cefazolin', 'cefoxitin', 'cefsulodin',
#          'ceftazidime', 'ciprofloxacin',
#          'ciprofloxacin imipenem ampicillin penicillin g oxacillin cefazolin ceftazidime cefoxitin cefsulodin aztreonam piperacillin amikacin spectinomycin doxycycline erythromycin metronidazole',
#          'ciprofloxacin pd 131628', 'doxycycline', 'erythromycin',
#          'fluorocyclopropyl naphthyridine quinolone', 'imipenem',
#          'metronidazole', 'oxacillin', 'pd', 'pd 131628', 'penicillin',
#          'penicillin g', 'piperacillin', 'quinolones', 'spectinomycin',
#          'vancomycin'], dtype=object),
#   array([3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 1, 1, 3, 3, 2, 3, 3, 3, 1, 3, 1, 2,
#          3, 4, 3, 4])),
#  (array(['-', '- 83698', 'bb', 'bb-83698', 'hydroxamic', 'hydroxamic acids',
#          'lbm-415', 'lbm-415)', 'methionine', 'n', 'n-formyl', 'nvp',
#          'nvp lbm', 'pdis', 'pseudopeptide hydroxamic acids'], dtype=object),
#   array([1, 1, 1, 2, 1, 2, 1, 1, 4, 2, 2, 1, 1, 1, 1])),
#  (array(['-', '- 83698', 'bb', 'bb-83698', 'hydroxamic', 'hydroxamic acids',
#          'lbm-415', 'lbm-415)', 'methionine', 'n', 'n-formyl', 'nvp',
#          'nvp lbm', 'pdis', 'pseudopeptide hydroxamic acids'], dtype=object),
#   array([1, 1, 1, 2, 1, 2, 1, 1, 4, 2, 2, 1, 1, 1, 1])),
#  (array(['-', '- 83698', 'bb', 'bb-83698', 'hydroxamic', 'hydroxamic acids',
#          'lbm-415', 'lbm-415)', 'methionine', 'n', 'n-formyl', 'nvp',
#          'nvp lbm', 'pdis', 'pseudopeptide hydroxamic acids'], dtype=object),
#   array([1, 1, 1, 2, 1, 2, 1, 1, 4, 2, 2, 1, 1, 1, 1])),
#  (array([], dtype=object), array([], dtype=int64)),
#  (array(['etx0914', 'fluoroquinolone', 'oxazolidinone'], dtype=object),
#   array([4, 4, 4])),
#  (array(['benzamide', 'benzamide compounds', 'cf3', 'cl', 'daptomycin',
#          'ftsz', 'linezolid', 'methicillin', 'methicillin-resistant',
#          'methicillin-sensitive', 'pc190723', 'pyridyl', 'txa707', 'txa709',
#          'txy541', 'txy541)', 'vancomycin', 'vancomycin daptomycin'],
#         dtype=object),
#   array([3, 1, 3, 4, 3, 1, 4, 3, 1, 1, 4, 4, 4, 4, 4, 1, 3, 1])),
#  (array(['phenothiazine', 'ring sulphoxide', 'sulphoxide', 'thioridazine'],
#         dtype=object),
#   array([4, 1, 3, 4])),
#  (array(['1', '1 2 4-oxadiazole', '124-oxadiazole', 'methicillin',
#          'methicillin-resistant'], dtype=object),
#   array([1, 2, 1, 3, 1])),
#  (array(['daptomycin', 'lysostaphin', 'methicillin',
#          'methicillin-resistant'], dtype=object),
#   array([4, 2, 3, 1])),
#  (array(['colistin', 'colistin-resistant', 'octapeptin', 'octapeptin c4',
#          'octapeptins', 'octb'], dtype=object),
#   array([4, 1, 2, 2, 2, 1])),
#  (array(['actinocarbasin', 'actinocarbasin m131', 'antibiotics', 'b',
#          'b-lactam', 'b-lactams', 'depsipeptide', 'imipenem',
#          'krisynomycin', 'lipoglycopeptide', 'm131', 'methicillin',
#          'methicillin-resistant', 'methicillin-sensitive', 'serine'],
#         dtype=object),
#   array([3, 1, 1, 1, 3, 3, 1, 4, 3, 3, 2, 3, 1, 1, 3])),
#  (array(['actinocarbasin', 'actinocarbasin m131', 'antibiotics', 'b',
#          'b-lactam', 'b-lactams', 'depsipeptide', 'imipenem',
#          'krisynomycin', 'lipoglycopeptide', 'm131', 'methicillin',
#          'methicillin-resistant', 'methicillin-sensitive', 'serine'],
#         dtype=object),
#   array([3, 1, 1, 1, 3, 3, 1, 4, 3, 3, 2, 3, 1, 1, 3])),
#  (array(['diacylglyceryl', 'g2824'], dtype=object), array([3, 3])),
#  (array(['g0507', 'lolcde', 'pyrrolopyrimidinedione', 'se'], dtype=object),
#   array([3, 1, 4, 2])),
#  (array(['aminoacyl', 'aminomethylbenzoxaboroles', 'an3365', 'boron',
#          'boron-based', 'leucyl', 'oxaborole'], dtype=object),
#   array([2, 4, 4, 3, 1, 3, 4])),
#  (array(['cbr', 'cbr hydroxamidine cbr703', 'cbr hydroxamidines',
#          'cbr hydroxamidines cbr hydroxamidines', 'cbr pyrazole',
#          'cbr pyrazoles', 'cbr703', 'hydroxamidine', 'hydroxamidines',
#          'pyrazole', 'pyrazoles'], dtype=object),
#   array([2, 1, 2, 1, 2, 2, 3, 2, 1, 1, 4])),
#  (array(['biotin', 'glycine', 'mac13772', 'mac168425',
#          'mac168425 mac173979', 'mac173979', 'p', 'p-aminobenzoic acid'],
#         dtype=object),
#   array([4, 4, 4, 4, 1, 4, 1, 3])),
#  (array(['ampicillin', 'azithromycin', 'cefixime', 'ceftriaxone',
#          'ceftriaxone cefixime azithromycin ciprofloxacin ampicillin spectinomycin',
#          'ciprofloxacin', 'dis', 'dis-73285', 'spectinomycin',
#          'tetracycline', 'tetracycline dis-73285'], dtype=object),
#   array([3, 3, 3, 3, 1, 3, 1, 3, 3, 3, 1])),
#  (array(['-', '- ester', '3', '3 -ester', '3 -noviose',
#          '3 -substituted noviose sugar',
#          '3-amino-4-hydroxy-8-methyl-7-[ 3-o-(5-methyl-2-pyrrolylcarbonyl)novio',
#          '3-ester-linked 5-methylpyrrole', '3-noviose', '4',
#          '4-hydroxy-8-methylcoumarin',
#          '4-hydroxyl-3-(3-methyl-2-butenyl)benzoic acid', '5',
#          '5-methylpyrrole', '7', '7 ether', 'alkyl', 'amide', 'aryl',
#          'clorobiocin', 'coumarin', 'coumarin)',
#          'coumarin-noviose-5-methylpyrrole', 'coumermycin',
#          'coumermycin a1', 'ether', 'isobutyryl', 'isobutyryl pnc-nh2',
#          'methylpyrrole', 'noviose', 'noviose sugar',
#          'noviose-5-methylpyrrole', 'novobiocin', 'novobiocin coumermycin',
#          'novobiocin coumermycin a1', 'pnc', 'pnc-nh2', 'pyrrole'],
#         dtype=object),
#   array([1, 1, 1, 1, 2, 2, 2, 1, 1, 1, 3, 3, 2, 3, 1, 1, 4, 4, 4, 4, 4, 1,
#          1, 4, 3, 2, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 2, 4])),
#  (array(['aminoglycosides', 'capreomycin', 'tuberactinomycin',
#          'tuberactinomycins', 'viomycin'], dtype=object),
#   array([4, 4, 4, 4, 4])),
#  (array(['aminoglycoside', 'gentamicin', 'gentamicin sisomicin',
#          'sisomicin', 'tobramycin'], dtype=object),
#   array([4, 4, 1, 4, 4])),
#  (array(['4', '4 -bromo', '4 -butyl', '4 -chloro', '4 -chloro-bromo -',
#          '4 -ethylsulfanylnetilmicin', '4 -phenyl', '4-bromo', '4-butyl',
#          '4-chloro- bromo-', '4-ethylsulfanylnetilmicin', '4-phenyl',
#          'bromo', 'butyltrifluoroborate', 'ethanesulfenyl',
#          'ethanesulfenyl chloride', 'iodo', 'netilmicin', 'netilmicin 4 ',
#          'netilmicin sulfenylation', 'phenylboronic', 'phenylboronic acid'],
#         dtype=object),
#   array([1, 2, 2, 1, 1, 2, 2, 1, 1, 1, 1, 1, 1, 4, 1, 3, 3, 4, 1, 1, 1, 3])),
#  (array(['amikacin', 'amikacin mk0787', 'carbenicillin', 'cefaxolin',
#          'cefoxitin', 'cefoxitin cefaxolin carbenicillin', 'mk0787', 'n',
#          'n-formimidoyl thienamycin', 'thienamycin',
#          'thienamycin n-formimidoyl thienamycin'], dtype=object),
#   array([3, 1, 4, 3, 3, 1, 4, 1, 2, 3, 1])),
#  (array(['213689', 'creatinine', 'ici', 'ici 194 660', 'ici 213 689',
#          'meropenem'], dtype=object),
#   array([1, 4, 1, 2, 2, 4])),
#  (array(['carba', 'carbapenems', 'carbapenems ertapenem', 'ertapenem'],
#         dtype=object),
#   array([2, 4, 1, 4])),
#  (array(['amoxicillin', 'ampicillin', 'ampicillin-sulbactam', 'augmentin',
#          'beta', 'beta-lactam', 'cephalosporinases', 'cephalosporins',
#          'clavulanic', 'clavulanic acid', 'penicillins', 'sulbactam',
#          'sultamicillin', 'sultamicillin;', 'ticarcillin', 'timentin',
#          'timentin sulbactam'], dtype=object),
#   array([4, 4, 1, 2, 1, 2, 1, 3, 1, 3, 4, 4, 4, 1, 4, 1, 1])),
#  (array(['15', 'aai101', 'carbapenem', 'carbapenem-sparing', 'cefepime',
#          'cefepime-aai101', 'ctx', 'ctx-m-15', 'methyl', 'penicillanic',
#          'penicillanic acid', 'penicillanic acid sulfone', 'piperacillin',
#          'piperacillin-tazobactam', 'tazobactam', 'zwitterion'],
#         dtype=object),
#   array([1, 4, 3, 1, 4, 1, 3, 1, 4, 1, 1, 2, 3, 1, 4, 1])),
#  (array(['cephalexin', 'cephalosporin', 'cephalosporin c', 'penicillinase'],
#         dtype=object),
#   array([4, 1, 3, 1])),
#  (array(['cephalothin'], dtype=object), array([4])),
#  (array(['cephalosporin', 'cephalothin', 'cephapirin', 'indole'],
#         dtype=object),
#   array([4, 4, 4, 2])),
#  (array(['bl', 'bl-s640', 'cefatrizine', 'cefazolin', 'cephalexin',
#          'cephalosporins', 'cephalothin', 'cephapirin',
#          'cephapirin cephalothin', 'indole'], dtype=object),
#   array([1, 3, 3, 4, 4, 4, 3, 3, 1, 2])),
#  (array(['cefixime', 'cefprozil', 'cefprozil cefixime', 'ciprofloxacin',
#          'ciprofloxacin-resistant'], dtype=object),
#   array([4, 4, 1, 4, 1])),
#  (array(['flomoxef', 'oxacephem', 'oxacephem b-lactam'], dtype=object),
#   array([3, 1, 3])),
#  (array(['7',
#          '7 beta-[ 2-(2-aminothiazol-4-yl)-(z)-2-methoxyiminoacetamido ]-3-[(1-methyl-1h-tetrazol-5-yl)thiomethyl ] ceph-3-em-4-carboxylic acid',
#          'beta-[2-(2-aminothiazol-4-yl)-(z)-2-methoxyiminoacetamido]-3-[(1-methyl-1h-tetrazol-5-yl)thiomethyl]ceph-3-em-4-carboxylic acid',
#          'carbenicillin', 'cefmenoxime', 'cefsulodin', 'cephalosporins',
#          'cephalosporins cefmenoxime', 'penicillin', 'sce', 'sce-1365',
#          'sulbenicillin'], dtype=object),
#   array([1, 2, 1, 4, 4, 4, 4, 1, 3, 1, 2, 4])),
#  (array(['ceftriaxone'], dtype=object), array([4])),
#  (array(['cefozopran', 'cefozopran hydrochloride', 'cephalosporin'],
#         dtype=object),
#   array([4, 3, 4])),
#  (array(['beta', 'beta-lactam', 'carbenicillin', 'penicillin',
#          'penicillin-binding'], dtype=object),
#   array([1, 3, 4, 3, 1])),
#  (array(['cloxacillin', 'cloxacillin;', 'dicloxacillin',
#          'dicloxacillin-flucloxacillin', 'flucloxacillin', 'isoxazole',
#          'isoxazole penicillin', 'isoxazole penicillins', 'oxacillin',
#          'oxacillin cloxacillin', 'penicillin', 'penicillin-resistant'],
#         dtype=object),
#   array([4, 1, 4, 1, 4, 1, 3, 3, 4, 1, 3, 1])),
#  (array(['6', '6(2 : 6-dimethoxybenzamido)-penicillanic acid',
#          'methicillin',
#          'methicillin 6(2:6-dimethoxybenzamido)-penicillanic acid',
#          'penicillin', 'penicillin g'], dtype=object),
#   array([1, 2, 3, 1, 1, 3])),
#  (array(['antistaphylococcal', 'antistaphylococcal penicillin', 'asp',
#          'cefazolin', 'cefazolin)', 'methicillin', 'methicillin-sensitive',
#          'penicillin'], dtype=object),
#   array([1, 1, 4, 4, 1, 3, 1, 1])),
#  (array(['penicillin', 'sulbactam'], dtype=object), array([2, 4])),
#  (array(['36', '5', 'boronic', 'boronic acid', 'boronic acid-containing',
#          'ceftibuten', 'cephalosporin', 'etzadroxil', 'etzadroxil)', 'vnrx',
#          'vnrx-5236', 'vnrx-7145'], dtype=object),
#   array([1, 1, 1, 2, 1, 4, 3, 3, 1, 1, 2, 2])),
#  (array(['b', 'b-lactam', 'blis', 'carbapenem', 'carbapenem-resistant',
#          'carbon', 'carbon -', 'carbon-carbon', 'cefpodoxime',
#          'cefpodoxime proxetil', 'dbo', 'dbo etx1317', 'diazabicyclooctane',
#          'ester', 'etx0282', 'etx1317', 'etx1317 etx0282', 'fluoroacetate',
#          'serine'], dtype=object),
#   array([1, 3, 1, 3, 1, 3, 1, 1, 1, 3, 3, 1, 4, 4, 3, 3, 1, 4, 3])),
#  (array(['purine', 'sulphonamide', 'sulphonamides', 'trimethoprim'],
#         dtype=object),
#   array([3, 4, 4, 4])),
#  (array(['dapsone', 'dds', 'dihydrofolate', 'epiroprim', 'epm', 'ro',
#          'ro 11-8958', 'ro 11-8958)', 'smz', 'sulfamethoxazole', 'tmp',
#          'trimethoprim'], dtype=object),
#   array([4, 3, 3, 4, 4, 1, 2, 1, 3, 4, 3, 4])),
#  (array(['linezolid', 'lipoglycopeptide', 'methicillin', 'telavancin',
#          'vancomycin'], dtype=object),
#   array([4, 1, 3, 4, 4])),
#  (array(['lincomycin'], dtype=object), array([4])),
#  (array(['clindamycin', 'clindamycins'], dtype=object), array([4, 1])),
#  (array(['ampicillin', 'cefotaxime', 'cefoxitin', 'clindamycin',
#          'daptomycin', 'deptomycin', 'erythromycin',
#          'erythromycin deptomycin clindamycin', 'gentamicin', 'penicillin',
#          'penicillin ampicillin', 'vancomycin', 'vancomycin-resistant'],
#         dtype=object),
#   array([3, 4, 4, 3, 4, 3, 3, 1, 4, 3, 1, 4, 1])),
#  (array(['(', '(13)c-urea', 'amoxicillin', 'bismuth', 'furazolidone',
#          'furazolidone-based', 'rabeprazole'], dtype=object),
#   array([1, 3, 4, 4, 4, 1, 4])),
#  (array(['nifurt', 'nifurtimox'], dtype=object), array([1, 3])),
#  (array(['methicillin', 'methicillin-resistant', 'mupirocin',
#          'mupirocin-resistant', 'retapamulin'], dtype=object),
#   array([3, 1, 3, 1, 4])),
#  (array(['bicyclolide', 'bridged bicyclolide', 'edp', 'edp-420', 'ep',
#          'ep-013420', 'macrolide', 'macrolide antibiotics edp-420', 's',
#          's-013420', 's-013420)'], dtype=object),
#   array([3, 1, 1, 3, 1, 3, 3, 1, 1, 2, 1])),
#  (array(['antepartum', 'folinic', 'folinic acid', 'pyrimethamine',
#          'pyrimethamine-sulfonamide-folinic acid', 'spiramycin',
#          'sulfonamide'], dtype=object),
#   array([1, 1, 1, 2, 2, 4, 1])),
#  (array(['actinorhodin', 'caprazamycin', 'cholesterol', 'daunorubicin',
#          'oleandomycin', 'polyketides', 'rapamycin',
#          'rapamycin oleandomycin actinorhodin daunorubicin'], dtype=object),
#   array([3, 4, 3, 3, 3, 3, 3, 1])),
#  (array(['mycalamide', 'mycalamide a', 'triacetyloleandomycin'],
#         dtype=object),
#   array([1, 3, 4])),
#  (array(['alpha', 'alpha-6-deoxy-oxytetracycline', 'compounds',
#          'demethylchlortetracycline', 'doxycycline', 'tetracycline'],
#         dtype=object),
#   array([1, 2, 1, 4, 4, 4])),
#  (array(['b', 'b-lactam', 'b-lactam antibiotic', 'eravacycline',
#          'eravacycline tigecycline', 'omadacycline', 'penicillin',
#          'tetracycline', 'tetracycline-class',
#          'tetracycline-class antibiotics',
#          'tetracycline-class antibiotics eravacycline omadacycline',
#          'tetracyclines', 'tigecycline'], dtype=object),
#   array([1, 2, 1, 3, 1, 4, 4, 4, 1, 1, 1, 4, 4])),
#  (array(['demeclocycline', 'medline((r))', 'sodium'], dtype=object),
#   array([4, 1, 4])),
#  (array(['colistin', 'polymyxin', 'polymyxin b',
#          'polymyxin-like lipopeptides', 'polymyxins'], dtype=object),
#   array([4, 4, 3, 1, 4])),
#  (array(['tyrocidine', 'tyrothricin'], dtype=object), array([4, 4])),
#  (array(['gramicidin', 'gramicidin-the', 'penicillin'], dtype=object),
#   array([2, 1, 4])),
#  (array(['ciprofloxacin', 'fluoroquinolone', 'prulifloxacin', 'ulifloxacin'],
#         dtype=object),
#   array([4, 4, 4, 4])),
#  (array(['ciprofloxacin', 'clinafloxacin', 'clinafloxacin)', 'enoxacin',
#          'enoxacin fleroxacin ciprofloxacin lomefloxacin trovafloxacin grepafloxacin ofloxacin',
#          'fleroxacin', 'gatifloxacin', 'grepafloxacin', 'levofloxacin',
#          'levofloxacin)', 'lomefloxacin', 'moxifloxacin', 'nadifloxacin',
#          'nadifloxacin)', 'norfloxacin', 'ofloxacin', 'pazufloxacin',
#          'pazufloxacin moxifloxacin', 'quinolones', 'sparfloxacin',
#          'trovafloxacin'], dtype=object),
#   array([3, 3, 1, 3, 1, 3, 3, 3, 3, 1, 3, 3, 4, 1, 4, 3, 3, 1, 4, 3, 3])),
#  (array(['ampicillin-', 'c-10', 'ceftazidime', 'ceftazidime-resistant',
#          'ciprofloxacin', 'ciprofloxacin-resistant', 'cyclopropyl',
#          'fleroxacin', 'fluoroquinolone', 'gentamicin', 'gentamicin-',
#          'imipenem', 'imipenem-resistant', 'methicillin',
#          'methicillin-susceptible', 'minocycline', 'minocycline-',
#          'norfloxacin', 'norfloxacin ofloxacin', 'ofloxacin', 'oxazine',
#          't-3761', 'tosufloxacin'], dtype=object),
#   array([1, 1, 2, 1, 3, 1, 3, 3, 3, 2, 1, 2, 1, 2, 1, 2, 1, 3, 1, 3, 3, 3,
#          3])),
#  (array(['carbonyl', 'fluoroquinolone', 'fluoroquinolone pefloxacin',
#          'fluoroquinolones', 'n', 'n-acetylcysteine', 'pefloxacin',
#          'pefloxacin-induced', 'radiosulfate', 'sulfate',
#          'sulfate pefloxacin'], dtype=object),
#   array([4, 2, 2, 4, 1, 3, 4, 1, 3, 4, 1])),
#  (array(['sp600125', 'tnf', 'trovafloxacin', 'tvx'], dtype=object),
#   array([4, 1, 4, 3])),
#  (array(['avarofloxacin',
#          'avarofloxacin delafloxacin finafloxacin zabofloxacin', 'bicyclic',
#          'ciprofloxacin', 'delafloxacin', 'finafloxacin', 'fluorine',
#          'fluoroquinolones', 'levofloxacin', 'moxifloxacin', 'nemonoxacin',
#          'non-fluorinated nemonoxacin', 'norfloxacin',
#          'norfloxacin ciprofloxacin levofloxacin moxifloxacin', 'quinolone',
#          'quinolones', 'zabofloxacin'], dtype=object),
#   array([3, 1, 1, 4, 3, 3, 4, 4, 3, 3, 3, 1, 3, 1, 4, 4, 3])),
#  (array(['avarofloxacin',
#          'avarofloxacin delafloxacin finafloxacin zabofloxacin', 'bicyclic',
#          'ciprofloxacin', 'delafloxacin', 'finafloxacin', 'fluorine',
#          'fluoroquinolones', 'levofloxacin', 'moxifloxacin', 'nemonoxacin',
#          'non-fluorinated nemonoxacin', 'norfloxacin',
#          'norfloxacin ciprofloxacin levofloxacin moxifloxacin', 'quinolone',
#          'quinolones', 'zabofloxacin'], dtype=object),
#   array([3, 1, 1, 4, 3, 3, 4, 4, 3, 3, 3, 1, 3, 1, 4, 4, 3])),
#  (array(['besifloxacin',
#          'besifloxacin delafoxacin finafloxacin lascufloxacin nadifloxacin',
#          'delafoxacin', 'finafloxacin', 'fluoroquinolones', 'lascufloxacin',
#          'levonadifloxacin', 'levonadifloxacin nemonoxacin', 'nadifloxacin',
#          'nadifloxacin)', 'nemonoxacin', 'quinolones', 'zabofloxacin'],
#         dtype=object),
#   array([3, 1, 3, 3, 4, 3, 3, 1, 3, 1, 3, 4, 4])),
#  (array(['besifloxacin',
#          'besifloxacin delafoxacin finafloxacin lascufloxacin nadifloxacin',
#          'delafoxacin', 'finafloxacin', 'fluoroquinolones', 'lascufloxacin',
#          'levonadifloxacin', 'levonadifloxacin nemonoxacin', 'nadifloxacin',
#          'nadifloxacin)', 'nemonoxacin', 'quinolones', 'zabofloxacin'],
#         dtype=object),
#   array([3, 1, 3, 3, 4, 3, 3, 1, 3, 1, 3, 4, 4])),
#  (array(['amodiaquine', 'aq fdc', 'artemisinin', 'artemisinin-combination',
#          'artesunate', 'artesunate/amodiaquine',
#          'artesunate/sulphamethoxypyrazine/pyrimethamine', 'as',
#          'as + smp fdc', 'bilirubin', 'pyrimethamine', 'smp)',
#          'sulphamethoxypyrazine'], dtype=object),
#   array([2, 1, 3, 1, 3, 1, 1, 1, 1, 3, 3, 1, 2])),
#  (array(['ampicillin', 'sulphamethoxazole', 'trimethoprim',
#          'trimethoprim-sulphamethoxazole'], dtype=object),
#   array([4, 4, 4, 1])),
#  (array(['deoxyribonucleic acid', 'drug', 'sulfur', 'sulfur-containing',
#          'thiolutin'], dtype=object),
#   array([1, 1, 3, 1, 4])),
#  (array(['corallopyronin', 'corallopyronin a', 'holomycin', 'rifampin',
#          'rifampin-resistant', 'ripostatin', 'ripostatin a', 'sorangicin',
#          'sorangicin a', 'streptolydigin', 'thiolutin',
#          'thiolutin holomycin corallopyronin a'], dtype=object),
#   array([1, 2, 3, 3, 1, 1, 3, 1, 3, 4, 3, 1])),
#  (array(['2', '2 3-diaminobutyric acid', '23-diaminobutyric acid', 'acid',
#          'acid acyl', 'acyl', 'amino', 'amino acid', 'amino acids',
#          'daptomycin', 'fatty', 'fatty acid', 'fatty acid acyl',
#          'friulimicin', 'l', 'l-pipecolinic acid', 'lysine',
#          'methylaspartic', 'methylaspartic acid', 'pipecolinic',
#          'pipecolinic acid', 'pipecolinic acid methylaspartic acid'],
#         dtype=object),
#   array([1, 2, 1, 1, 1, 1, 1, 2, 2, 4, 1, 2, 1, 4, 1, 3, 3, 1, 2, 1, 2, 1])),
#  (array(['deoxyribonucleic acid', 'nucleoside', 'nucleoside triphosphate',
#          'nucleoside triphosphate-pyrophosphate', 'pyrophosphate',
#          'ribonucleic', 'rifamycin', 'streptolydigin'], dtype=object),
#   array([2, 1, 2, 1, 3, 1, 4, 4])),
#  (array(['(sodium salt)', '1',
#          '1-palmitoyl-2-oleoyl-sn-glycero-3-phospho-(1 -rac-glycerol)',
#          '1-palmitoyl-2-oleoyl-sn-glycero-3-phosphocholine', 'acid',
#          'amphomycin', 'amphomycin)', 'c55', 'c55-p', 'ca2', 'ca2 +',
#          'ca2+-dependent lipopeptide', 'calcein', 'calcium',
#          'calcium-dependent lipopeptide', 'carbohydrate', 'daptomycin',
#          'daptomycin mx-2401', 'lipopeptide daptomycin', 'mx', 'mx-2401',
#          'popc', 'popg', 'sodium salt', 'teichoic acid',
#          'undecaprenylphosphate'], dtype=object),
#   array([1, 1, 2, 3, 1, 3, 1, 1, 3, 1, 2, 1, 3, 3, 1, 3, 4, 1, 1, 1, 3, 3,
#          2, 2, 1, 4])),
#  (array(['muraymycin', 'muraymycins', 'nucleoside', 'uridine',
#          'uridine-derived'], dtype=object),
#   array([3, 3, 3, 3, 1])),
#  (array(['- 90289', '- b', '2', '2 5-dideoxy-5-aminoribose',
#          '2 5-dideoxy-5-aminoribose saccharide', '2-deoxy',
#          '2-deoxy sugars', '25-dideoxy-5-aminoribose saccharide', '5',
#          '5 -amino-2 5 -dideoxyuridine',
#          '5-amino-2 5-dideoxy-a-d-ribose-1-phosphate', '90289', 'a',
#          'a-90289', 'disaccharide', 'lipopeptidyl', 'muraminomicin',
#          'muraymycin', 'nucleoside', 'o', 'o-b', 'o-b(1-5)', 'ribofuranose',
#          'ribose', 'ribosyl', 'saccharide', 'sugar', 'utp'], dtype=object),
#   array([1, 1, 1, 1, 1, 1, 2, 1, 1, 2, 2, 1, 1, 2, 3, 1, 4, 4, 2, 1, 1, 1,
#          3, 3, 3, 1, 3, 2])),
#  (array(['carbapenem', 'carbapenem-resistant', 'halicin'], dtype=object),
#   array([3, 1, 4])),
#  (array(['acetamide', 'alkyl', 'c-5 acetamide-containing thiotetroamide',
#          'c-5 dialkyl', 'c-5 ethyl', 'carboxylic', 'carboxylic acid',
#          'dialkyl', 'ethyl', 'fatty', 'fatty acid', 'hydroxylate', 'n',
#          'nicotinamide', 'nicotinamide n', 'thiolactomycin',
#          'thiolactomycin thiotetromycin', 'thiotetroamide',
#          'thiotetromycin', 'thiotetronate', 'thiotetronate-containing',
#          'ttmn', 'ttmp'], dtype=object),
#   array([3, 3, 1, 1, 1, 2, 2, 3, 3, 1, 2, 2, 1, 2, 1, 3, 1, 4, 4, 4, 1, 1,
#          2])),
#  (array(['bama', 'h4', 'imb', 'imb -', 'imb-h4'], dtype=object),
#   array([2, 1, 2, 1, 1])),
#  (array(['desertomycin', 'desertomycin h', 'macrolactone', 'vancomycin',
#          'vancomycin-intermediate'], dtype=object),
#   array([1, 3, 4, 3, 1])),
#  (array(['amide', 'boron', 'boron heterocycle', 'diazaborine',
#          'diazaborines', 'enoyl', 'enoyl-acp', 'fatty', 'fatty-acid',
#          'isoniazid', 'sulfonyl', 'sulfonyl-containing', 'thioamide'],
#         dtype=object),
#   array([4, 3, 1, 4, 4, 2, 1, 1, 2, 4, 4, 1, 4])),
#  (array(['imb-0042', 'lipopolysaccharide', 'lps'], dtype=object),
#   array([3, 1, 1])),
#  (array(['(', '2', '2-amino-3-methyl-1-butanol',
#          '2-amino-3-methyl-1-butanol)', '2-hydroxy-3-methylpentanoic acid',
#          'a', 'a b-didehydrobutyric acid', 'ab-didehydrobutyric acid',
#          'ab-didehydrobutyric acid ornithine', 'amino', 'amino acid',
#          'amino acids', 'brevibacillin', 'c6', 'c6 fatty acid', 'dhb', 'fa',
#          'fa-dhb-leu-orn-ile-ile-val-lys-val-val-lys-tyr-leu-valinol',
#          'fatty acid', 'isopropanol', 'methicillin',
#          'methicillin-resistant', 'n', 'ornithine', 'valinol', 'vancomycin',
#          'vancomycin-resistant'], dtype=object),
#   array([1, 1, 2, 1, 3, 1, 2, 1, 1, 2, 2, 2, 4, 1, 1, 4, 1, 2, 2, 4, 3, 1,
#          2, 3, 4, 3, 1])),
#  (array(['b', 'bogorol', 'bogorols', 'lipid', 'lys3', 'orn3/lys3',
#          'relacidines', 'succilins', 'succinyl', 'succinylated bogorols',
#          'succinylation', 'valinol'], dtype=object),
#   array([2, 3, 3, 1, 1, 1, 2, 2, 3, 2, 1, 3])),
#  (array(['am8085', 'am8191', 'asp83b', 'aspartate', 'h', 'nbti', 'nbtis',
#          'nh', 'oxabicyclooctane', 'oxabicyclooctane-linked nbtis',
#          'quinolones'], dtype=object),
#   array([4, 4, 3, 3, 2, 1, 3, 3, 3, 1, 4])),
#  (array(['3-(s)', 'aminomethyl', 'aminomethyl spectinomycin',
#          'cephalosporin', 'cephalosporin-resistant', 'macrolide', 'n',
#          'n-benzyl aminomethyl spectinomycins',
#          'n-benzyl-substituted 3 -(r)-3 -aminomethyl-3 -hydroxy spectinomycins',
#          'n-benzyl-substituted 3-(r)-3-aminomethyl-3-hydroxy spectinomycins',
#          'penicillin', 'penicillin- macrolide-', 'spectinomycin',
#          'spectinomycin;'], dtype=object),
#   array([1, 1, 3, 3, 1, 3, 1, 3, 2, 1, 3, 1, 4, 1])),
#  (array(['3-(s)', 'aminomethyl', 'aminomethyl spectinomycin',
#          'cephalosporin', 'cephalosporin-resistant', 'macrolide', 'n',
#          'n-benzyl aminomethyl spectinomycins',
#          'n-benzyl-substituted 3 -(r)-3 -aminomethyl-3 -hydroxy spectinomycins',
#          'n-benzyl-substituted 3-(r)-3-aminomethyl-3-hydroxy spectinomycins',
#          'penicillin', 'penicillin- macrolide-', 'spectinomycin',
#          'spectinomycin;'], dtype=object),
#   array([1, 1, 3, 3, 1, 3, 1, 3, 2, 1, 3, 1, 4, 1])),
#  (array(['3-(s)', 'aminomethyl', 'aminomethyl spectinomycin',
#          'cephalosporin', 'cephalosporin-resistant', 'macrolide', 'n',
#          'n-benzyl aminomethyl spectinomycins',
#          'n-benzyl-substituted 3 -(r)-3 -aminomethyl-3 -hydroxy spectinomycins',
#          'n-benzyl-substituted 3-(r)-3-aminomethyl-3-hydroxy spectinomycins',
#          'penicillin', 'penicillin- macrolide-', 'spectinomycin',
#          'spectinomycin;'], dtype=object),
#   array([1, 1, 3, 3, 1, 3, 1, 3, 2, 1, 3, 1, 4, 1])),
#  (array(['3-(s)', 'aminomethyl', 'aminomethyl spectinomycin',
#          'cephalosporin', 'cephalosporin-resistant', 'macrolide', 'n',
#          'n-benzyl aminomethyl spectinomycins',
#          'n-benzyl-substituted 3 -(r)-3 -aminomethyl-3 -hydroxy spectinomycins',
#          'n-benzyl-substituted 3-(r)-3-aminomethyl-3-hydroxy spectinomycins',
#          'penicillin', 'penicillin- macrolide-', 'spectinomycin',
#          'spectinomycin;'], dtype=object),
#   array([1, 1, 3, 3, 1, 3, 1, 3, 2, 1, 3, 1, 4, 1])),
#  (array(['9 -3h ]', '[', '[ 14c ] ile', '[ 14c ] ile approximately amp',
#          '[ 14c ] isoleucine', '[14c]ile approximately amp',
#          '[14c]isoleucine', 'amp', 'approximately amp', 'ile',
#          'ile approximately amp', 'isoleucine', 'isoleucyl',
#          'pyrophosphate', 'sodium', 'sodium [ 9 -3h ]',
#          'sodium [ 9 -3h ] pseudomonate', 'sodium [9-3h]pseudomonate',
#          'sodium dodecyl sulphate', 'sodium pseudomonate', 'urea'],
#         dtype=object),
#   array([1, 1, 1, 1, 2, 1, 1, 2, 1, 2, 1, 4, 1, 3, 2, 1, 1, 1, 3, 3, 3])),
#  (array(['4', '4-(tert-butylamino)methyl', '4-aminomethylated', 'ala262',
#          'heliomycin', 'hydrogen', 'ile347'], dtype=object),
#   array([1, 3, 1, 4, 4, 3, 4])),
#  (array(['(', '(14)c-biotin', '(14)c-pimelic acid', 'beta',
#          'beta-methylbiotin', 'beta-methylbiotin(14)c-biotin',
#          'beta-methyldethiobiotin', 'biotin'], dtype=object),
#   array([1, 2, 3, 1, 2, 1, 3, 4])),
#  (array(['(', '(14)c-biotin', '(14)c-pimelic acid', 'beta',
#          'beta-methylbiotin', 'beta-methylbiotin(14)c-biotin',
#          'beta-methyldethiobiotin', 'biotin'], dtype=object),
#   array([1, 2, 3, 1, 2, 1, 3, 4])),
#  (array(['amino', 'amino acid', 'amino acids', 'aminonucleoside', 'biotin',
#          'c', 'nucleoside', 'puromycin', 'puromycin-based'], dtype=object),
#   array([1, 2, 2, 3, 4, 2, 3, 3, 1])),
#  (array(['a2', 'a2-rhodomycin ii', 'aglycones', 'ethyl', 'ethyl acetate',
#          'obelmycin', 'rhodomycin', 'rhodomycin b', 'sugars'], dtype=object),
#   array([1, 3, 1, 1, 3, 4, 4, 2, 4])),
#  (array(['salinomycin'], dtype=object), array([4])),
#  (array(['-', '- f', 'carbamoylated', 'carbamoylated gulosamine',
#          'carbapenem', 'carbapenem-resistant', 'guanine', 'gulosamine',
#          'hydrogen', 'lysine', 'lysine)', 'lysines', 'lysines)',
#          'nourseothricin', 'nucleobase', 's', 's-d', 's-f',
#          's-f steptolidine', 'steptolidine', 'streptothricin',
#          'streptothricin d', 'streptothricin f'], dtype=object),
#   array([1, 1, 1, 1, 2, 1, 4, 2, 3, 3, 1, 3, 1, 3, 2, 1, 2, 2, 1, 3, 4, 2,
#          2])),
#  (array(['valinomycin'], dtype=object), array([4])),
#  (array(['acetyl', 'acetylated viomycin', 'amino', 'amino acid', 'beta',
#          'beta-amino', 'beta-lysine', 'capreomycin', 'carbamoyl',
#          'cyclic pentapeptide', 'l', 'l-2 3-diaminopropionate',
#          'l-23-diaminopropionate', 'tuberactinomycin', 'tuberactinomycins',
#          'viol', 'viomycin', 'vioq'], dtype=object),
#   array([4, 1, 2, 2, 1, 2, 3, 4, 4, 1, 1, 2, 1, 3, 4, 2, 4, 1]))]

# %%
with_pmc['Combined words 2/4'] = [all_res[i][0][all_res[i][1] >= 2] for i in range(len(all_res))]
with_pmc['Combined words 3/4'] = [all_res[i][0][all_res[i][1] >= 3] for i in range(len(all_res))]
with_pmc['Combined words 4/4'] = [all_res[i][0][all_res[i][1] == 4] for i in range(len(all_res))]
# Out:
# <ipython-input-62-d64e75d73f4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   with_pmc['Combined words 2/4'] = [all_res[i][0][all_res[i][1] >= 2] for i in range(len(all_res))]
# <ipython-input-62-d64e75d73f4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   with_pmc['Combined words 3/4'] = [all_res[i][0][all_res[i][1] >= 3] for i in range(len(all_res))]
# <ipython-input-62-d64e75d73f4c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   with_pmc['Combined words 4/4'] = [all_res[i][0][all_res[i][1] == 4] for i in range(len(all_res))]

# %%
with_pmc
# Out:
#         PMC_ID      PMID                                              Title  \
# 1      4790266  27029317  Pipeline of Known Chemical Classes of Antibiot...
# 31     3318344  22232283  In vitro potential of equine DEFA1 and eCATH1 ...
# 34     4249419  25199778  Effective control of Salmonella infections by ...
# 35     4249419  25199778  Effective control of Salmonella infections by ...
# 36     4249444  25199777  In vitro potential of Lycosin-I as an alternat...
# ...        ...       ...                                                ...
# 2716   3667366  23741637  Rhodomycin analogues from Streptomyces purpura...
# 2725   4102832  23931281  Salinomycin: a novel anti-cancer agent with kn...
# 2746  10187937  37192172  Streptothricin F is a bactericidal antibiotic ...
# 2775   8068249  33917912  The Nonribosomal Peptide Valinomycin: From Dis...
# 2778   2765823  19105177  Investigations into viomycin biosynthesis by u...
#
#                                                Abstract  \
# 1     Many approaches are used to discover new antib...
# 31    Rhodococcus equi, the causal agent of rhodococ...
# 34    We successfully produced two human β-defensins...
# 35    We successfully produced two human β-defensins...
# 36    The resistance of multidrug-resistant Acinetob...
# ...                                                 ...
# 2716  During a screening program for bioactive natur...
# 2725  Salinomycin, traditionally used as an anti-coc...
# 2746  The streptothricin natural product mixture (al...
# 2775  Valinomycin is a nonribosomal peptide that was...
# 2778  Viomycin and capreomycin are members of the tu...
#
#                                                  Target  \
# 1                              [fy-901, aminoglycoside]
# 31                      [ecath1, antimicrobial peptide]
# 34                       [hbd-1, antimicrobial peptide]
# 35                       [hbd-2, antimicrobial peptide]
# 36                   [lycosin 1, antimicrobial peptide]
# ...                                                 ...
# 2716                        [rhodomycin, anthracycline]
# 2725    [salinomycin, polyether antibiotic (ionophore)]
# 2746                   [streptothricin, streptothricin]
# 2775  [valinomycin, antimicrobial peptide (cyclodode...
# 2778  [viomycin, celiomycin, florimycin, tuberactino...
#
#                                        Abstract_preproc  \
# 1     many approaches are used to discover new antib...
# 31    rhodococcus equi, the causal agent of rhodococ...
# 34    we successfully produced two human b-defensins...
# 35    we successfully produced two human b-defensins...
# 36    the resistance of multidrug-resistant acinetob...
# ...                                                 ...
# 2716  during a screening program for bioactive natur...
# 2725  salinomycin, traditionally used as an anti-coc...
# 2746  the streptothricin natural product mixture (al...
# 2775  valinomycin is a nonribosomal peptide that was...
# 2778  viomycin and capreomycin are members of the tu...
#
#                                                Raynardj  \
# 1     [lipopeptides, quinolones aminoglycosides macr...
# 31                                   [ecath1, rifampin]
# 34                                                   []
# 35                                                   []
# 36          [ca(2+)), d-lycosin-i, l-, lycosin-i, salt]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, aglycones, ethyl acetate, o...
# 2725                                      [salinomycin]
# 2746  [carbapenem-resistant, guanine, gulosamine, ly...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino, beta-lysine, capreomycin, carb...
#
#                                              AlvaroAlon  \
# 1     [aminoglycosides, beta-lactams, lipoglycopepti...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36     [ca(2 +), l-and d-lycosin-i, lycosin-i, mg(2 +)]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [-, - f, carbapenem, guanine, gulosamine, hydr...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino acid, beta-amino, beta-lysine, ...
#
#                                                 AitsLab  \
# 1     [aminoglycosides, beta-lactams, macrolides, ox...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36     [ca(2 +), l-and d-lycosin-i, lycosin-i, mg(2 +)]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [carbamoylated gulosamine, guanine, hydrogen, ...
# 2775                                      [valinomycin]
# 2778  [acetyl, acetylated viomycin, amino acid, beta...
#
#                                                   Pruas  \
# 1     [aminoglycosides, beta, cyclic, lipoglycopepti...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36                                 [ca, l, lycosin, mg]
# ...                                                 ...
# 2716         [a2, ethyl, obelmycin, rhodomycin, sugars]
# 2725                                      [salinomycin]
# 2746  [carbamoylated, carbapenem, guanine, hydrogen,...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino, beta, capreomycin, carbamoyl, ...
#
#                                      Combined words 1/4  \
# 1     [aminoglycosides, beta, beta-lactams, cyclic, ...
# 31                                   [ecath1, rifampin]
# 34                                                   []
# 35                                                   []
# 36    [ca, ca(2 +), ca(2+)), d-lycosin-i, l, l-, l-a...
# ...                                                 ...
# 2716  [a2, a2-rhodomycin ii, aglycones, ethyl, ethyl...
# 2725                                      [salinomycin]
# 2746  [-, - f, carbamoylated, carbamoylated gulosami...
# 2775                                      [valinomycin]
# 2778  [acetyl, acetylated viomycin, amino, amino aci...
#
#                                      Combined words 2/4  \
# 1     [aminoglycosides, beta-lactams, lipoglycopepti...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36     [ca(2 +), l-and d-lycosin-i, lycosin-i, mg(2 +)]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [carbapenem, guanine, gulosamine, hydrogen, ly...
# 2775                                      [valinomycin]
# 2778  [acetyl, amino, amino acid, beta-amino, beta-l...
#
#                                      Combined words 3/4  \
# 1     [aminoglycosides, macrolides, oxazolidinones, ...
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36                                          [lycosin-i]
# ...                                                 ...
# 2716  [a2-rhodomycin ii, ethyl acetate, obelmycin, r...
# 2725                                      [salinomycin]
# 2746  [guanine, hydrogen, lysine, lysines, nourseoth...
# 2775                                      [valinomycin]
# 2778  [acetyl, beta-lysine, capreomycin, carbamoyl, ...
#
#                                      Combined words 4/4
# 1                                                    []
# 31                                           [rifampin]
# 34                                                   []
# 35                                                   []
# 36                                                   []
# ...                                                 ...
# 2716                    [obelmycin, rhodomycin, sugars]
# 2725                                      [salinomycin]
# 2746                          [guanine, streptothricin]
# 2775                                      [valinomycin]
# 2778  [acetyl, capreomycin, carbamoyl, tuberactinomy...
#
# [122 rows x 14 columns]

# %%
with_pmc.to_excel('DatasetPositivo.xlsx', index=False)
