# %% [markdown]
# ## Import and Data Load

# %%
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ## PubTator

# %%
def pubtator_generate_struct(pubt_data):
    pubt_res = []
    for dic in pubt_data:
        annot_type = dic['infons']['type']
        if annot_type == "Chemical":
            annot_text = dic['text']
            annot_loc = {'start': dic['locations'][0]['offset'],
                        'end': dic['locations'][0]['offset'] + dic['locations'][0]['length']}
            res = {'text': annot_text, 'location': annot_loc}
            pubt_res.append(res)
    return pubt_res

# %%
import time

def pubtator_process(id):

    url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/export/biocjson?pmids={id}&full=true"
    res = requests.get(url)
    print(id)
    res_js = json.loads(res.content)['PubTator3']

    # Only working with abstracts
    pubt_annot = res_js[0]['passages'][1]['annotations']
    display(pubt_annot)
    pubt_res = pubtator_generate_struct(pubt_annot)

    time.sleep(0.6)

    return pubt_res

# %% [markdown]
# ## Procesar Dataset Positivo

# %%
pos_df = pd.read_excel("DatasetPositiveNature.xlsx")
pos_df.dropna(subset=['Abstract'], inplace=True)
pos_df
# Out:
#                                                 Title      PMID  \
# 0   2-Pyrazol-1-yl-thiazole derivatives as novel h...  31358913
# 1   A choline binding polypeptide of LytA inhibits...  30127421
# 2   A naturally inspired antibiotic to target mult...  34987225
# 3   A new class of synthetic retinoid antibiotics ...  29590091
# 4   A novel, rationally designed, hybrid antimicro...  32499514
# ..                                                ...       ...
# 75  Total synthesis and antimicrobial evaluation o...  30181560
# 76  Venturicidin A, A Membrane-active Natural Prod...  32424122
# 77  Walkmycin B targets WalK (YycG), a histidine k...  20057515
# 78  Wychimicins, a new class of spirotetronate pol...  36071214
# 79  trans-Translation inhibitors bind to a novel s...  33741965
#
#                                               Targets  \
# 0                      ['2-(pyrazol-1-yl)- thiazole']
# 1                                            ['ChBp']
# 2                                       ['Macolacin']
# 3                                 ['CD1530', 'CD437']
# 4                                           ['PA-13']
# ..                                                ...
# 75  ['Albomycin', 'albomycin delta 2', 'grisein', ...
# 76                                 ['Venturicidin A']
# 77                                    ['Walkmycin B']
# 78                                     ['Wychimicin']
# 79                                       ['MBX-4132']
#
#                                              Abstract
# 0   The present report describes our efforts to id...
# 1   Streptococcus pneumoniae is a pathogen that ma...
# 2   Gram-negative bacteria are responsible for an ...
# 3   A challenge in the treatment of Staphylococcus...
# 4   Antimicrobial peptides (AMPs) are promising al...
# ..                                                ...
# 75  Development of effective antimicrobial agents ...
# 76  Despite the remarkable advances due to the dis...
# 77  The WalK (a histidine kinase)/WalR (a response...
# 78  In the course of our screening program for new...
# 79  Bacterial ribosome rescue pathways that remove...
#
# [80 rows x 4 columns]

# %%
pos_df['PMID'] = pos_df['PMID'].astype(int)
pos_df
# Out:
#                                                 Title      PMID  \
# 0   2-Pyrazol-1-yl-thiazole derivatives as novel h...  31358913
# 1   A choline binding polypeptide of LytA inhibits...  30127421
# 2   A naturally inspired antibiotic to target mult...  34987225
# 3   A new class of synthetic retinoid antibiotics ...  29590091
# 4   A novel, rationally designed, hybrid antimicro...  32499514
# ..                                                ...       ...
# 75  Total synthesis and antimicrobial evaluation o...  30181560
# 76  Venturicidin A, A Membrane-active Natural Prod...  32424122
# 77  Walkmycin B targets WalK (YycG), a histidine k...  20057515
# 78  Wychimicins, a new class of spirotetronate pol...  36071214
# 79  trans-Translation inhibitors bind to a novel s...  33741965
#
#                                               Targets  \
# 0                      ['2-(pyrazol-1-yl)- thiazole']
# 1                                            ['ChBp']
# 2                                       ['Macolacin']
# 3                                 ['CD1530', 'CD437']
# 4                                           ['PA-13']
# ..                                                ...
# 75  ['Albomycin', 'albomycin delta 2', 'grisein', ...
# 76                                 ['Venturicidin A']
# 77                                    ['Walkmycin B']
# 78                                     ['Wychimicin']
# 79                                       ['MBX-4132']
#
#                                              Abstract
# 0   The present report describes our efforts to id...
# 1   Streptococcus pneumoniae is a pathogen that ma...
# 2   Gram-negative bacteria are responsible for an ...
# 3   A challenge in the treatment of Staphylococcus...
# 4   Antimicrobial peptides (AMPs) are promising al...
# ..                                                ...
# 75  Development of effective antimicrobial agents ...
# 76  Despite the remarkable advances due to the dis...
# 77  The WalK (a histidine kinase)/WalR (a response...
# 78  In the course of our screening program for new...
# 79  Bacterial ribosome rescue pathways that remove...
#
# [80 rows x 4 columns]

# %%
pos_df['PubTator'] = pos_df['PMID'].apply(pubtator_process)
# Out:
# 31358913
# [{'id': '9',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': '2-pyrazol-1-yl-thiazole',
#   'locations': [{'offset': 584, 'length': 23}]},
#  {'id': '10',
#   'infons': {'identifier': '562',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [562],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 562,
#    'biotype': 'species',
#    'name': '562',
#    'accession': None},
#   'text': 'Escherichia coli',
#   'locations': [{'offset': 671, 'length': 16}]},
#  {'id': '11',
#   'infons': {'identifier': 'MESH:D004917',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D004917'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D004917',
#    'biotype': 'chemical',
#    'name': 'Erythromycin',
#    'accession': '@CHEMICAL_Erythromycin'},
#   'text': 'erythromycin',
#   'locations': [{'offset': 929, 'length': 12}]},
#  {'id': '12',
#   'infons': {'identifier': 'MESH:D064704',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D064704'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064704',
#    'biotype': 'chemical',
#    'name': 'Levofloxacin',
#    'accession': '@CHEMICAL_Levofloxacin'},
#   'text': 'levofloxacin',
#   'locations': [{'offset': 1003, 'length': 12}]},
#  {'id': '13',
#   'infons': {'identifier': 'CVCL:0045',
#    'type': 'CellLine',
#    'valid': True,
#    'normalized': ['0045'],
#    'database': 'cvcl',
#    'normalized_id': '0045',
#    'biotype': 'cellline',
#    'name': '0045',
#    'accession': None},
#   'text': 'HEK293',
#   'locations': [{'offset': 1109, 'length': 6}]},
#  {'id': '14',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'cytotoxicity',
#   'locations': [{'offset': 1229, 'length': 12}]},
#  {'id': '15',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': '2-pyrazol-1-yl-thiazoles',
#   'locations': [{'offset': 1249, 'length': 24}]}]
# 30127421
# [{'id': '13',
#   'infons': {'identifier': '1313',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1313],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1313,
#    'biotype': 'species',
#    'name': '1313',
#    'accession': None},
#   'text': 'Streptococcus pneumoniae',
#   'locations': [{'offset': 126, 'length': 24}]},
#  {'id': '14',
#   'infons': {'identifier': 'MESH:D011008',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D011008'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D011008',
#    'biotype': 'disease',
#    'name': 'Pneumococcal Infections',
#    'accession': '@DISEASE_Pneumococcal_Infections'},
#   'text': 'pneumococcal infections',
#   'locations': [{'offset': 304, 'length': 23}]},
#  {'id': '15',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. pneumoniae',
#   'locations': [{'offset': 401, 'length': 13}]},
#  {'id': '16',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. pneumoniae',
#   'locations': [{'offset': 608, 'length': 13}]},
#  {'id': '17',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'pneumococcal',
#   'locations': [{'offset': 675, 'length': 12}]},
#  {'id': '18',
#   'infons': {'identifier': 'CVCL:0045',
#    'type': 'CellLine',
#    'valid': True,
#    'normalized': ['0045'],
#    'database': 'cvcl',
#    'normalized_id': '0045',
#    'biotype': 'cellline',
#    'name': '0045',
#    'accession': None},
#   'text': '293t',
#   'locations': [{'offset': 772, 'length': 4}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:D002794',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002794'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002794',
#    'biotype': 'chemical',
#    'name': 'Choline',
#    'accession': '@CHEMICAL_Choline'},
#   'text': 'choline',
#   'locations': [{'offset': 906, 'length': 7}]},
#  {'id': '20',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'pneumococcal',
#   'locations': [{'offset': 1044, 'length': 12}]},
#  {'id': '21',
#   'infons': {'identifier': 'MESH:D011008',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D011008'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D011008',
#    'biotype': 'disease',
#    'name': 'Pneumococcal Infections',
#    'accession': '@DISEASE_Pneumococcal_Infections'},
#   'text': 'pneumococcal disease',
#   'locations': [{'offset': 1237, 'length': 20}]}]
# 34987225
# [{'id': '11',
#   'infons': {'identifier': 'MESH:D003643',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D003643'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D003643',
#    'biotype': 'disease',
#    'name': 'Death',
#    'accession': '@DISEASE_Death'},
#   'text': 'deaths',
#   'locations': [{'offset': 140, 'length': 6}]},
#  {'id': '12',
#   'infons': {'identifier': 'MESH:D020803',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D020803'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D020803',
#    'biotype': 'disease',
#    'name': 'Encephalitis Herpes Simplex',
#    'accession': '@DISEASE_Encephalitis_Herpes_Simplex'},
#   'text': 'infections1,2',
#   'locations': [{'offset': 178, 'length': 13}]},
#  {'id': '13',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'colistin3',
#   'locations': [{'offset': 465, 'length': 9}]},
#  {'id': '14',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'macolacin',
#   'locations': [{'offset': 1146, 'length': 9}]},
#  {'id': '15',
#   'infons': {'identifier': '470',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [470],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 470,
#    'biotype': 'species',
#    'name': '470',
#    'accession': None},
#   'text': 'Acinetobacter baumannii',
#   'locations': [{'offset': 1390, 'length': 23}]},
#  {'id': '16',
#   'infons': {'identifier': '485',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [485],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 485,
#    'biotype': 'species',
#    'name': '485',
#    'accession': None},
#   'text': 'Neisseria gonorrhoeae',
#   'locations': [{'offset': 1451, 'length': 21}]},
#  {'id': '17',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mouse',
#   'locations': [{'offset': 1592, 'length': 5}]},
#  {'id': '18',
#   'infons': {'identifier': 'MESH:D044504',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D044504'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D044504',
#    'biotype': 'disease',
#    'name': 'Enterocolitis Neutropenic',
#    'accession': '@DISEASE_Enterocolitis_Neutropenic'},
#   'text': 'neutropenic infection',
#   'locations': [{'offset': 1598, 'length': 21}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:C010574',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C010574'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C010574',
#    'biotype': 'chemical',
#    'name': 'biphenyl',
#    'accession': '@CHEMICAL_biphenyl'},
#   'text': 'biphenyl',
#   'locations': [{'offset': 1629, 'length': 8}]},
#  {'id': '20',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'macolacin',
#   'locations': [{'offset': 1650, 'length': 9}]},
#  {'id': '21',
#   'infons': {'identifier': '470',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [470],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 470,
#    'biotype': 'species',
#    'name': '470',
#    'accession': None},
#   'text': 'A. baumannii',
#   'locations': [{'offset': 1718, 'length': 12}]}]
# 29590091
# [{'id': '24',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Staphylococcus aureus infections',
#   'locations': [{'offset': 118, 'length': 32}]},
#  {'id': '25',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 177, 'length': 11}]},
#  {'id': '26',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. aureus',
#   'locations': [{'offset': 199, 'length': 9}]},
#  {'id': '27',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MRSA',
#   'locations': [{'offset': 210, 'length': 4}]},
#  {'id': '28',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infections',
#   'locations': [{'offset': 386, 'length': 10}]},
#  {'id': '29',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infections',
#   'locations': [{'offset': 464, 'length': 10}]},
#  {'id': '30',
#   'infons': {'identifier': '6239',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [6239],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 6239,
#    'biotype': 'species',
#    'name': '6239',
#    'accession': None},
#   'text': 'Caenorhabditis elegans',
#   'locations': [{'offset': 571, 'length': 22}]},
#  {'id': '31',
#   'infons': {'identifier': 'MESH:D013203',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D013203'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013203',
#    'biotype': 'disease',
#    'name': 'Staphylococcal Infections',
#    'accession': '@DISEASE_Staphylococcal_Infections'},
#   'text': 'MRSA infection',
#   'locations': [{'offset': 594, 'length': 14}]},
#  {'id': '32',
#   'infons': {'identifier': 'MESH:D012176',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012176'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012176',
#    'biotype': 'chemical',
#    'name': 'Retinoids',
#    'accession': '@CHEMICAL_Retinoids'},
#   'text': 'retinoids',
#   'locations': [{'offset': 642, 'length': 9}]},
#  {'id': '33',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MRSA',
#   'locations': [{'offset': 709, 'length': 4}]},
#  {'id': '34',
#   'infons': {'identifier': 'MESH:D008055',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008055'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008055',
#    'biotype': 'chemical',
#    'name': 'Lipids',
#    'accession': '@CHEMICAL_Lipids'},
#   'text': 'lipid',
#   'locations': [{'offset': 734, 'length': 5}]},
#  {'id': '35',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 810, 'length': 10}]},
#  {'id': '36',
#   'infons': {'identifier': 'MESH:D012176',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012176'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012176',
#    'biotype': 'chemical',
#    'name': 'Retinoids',
#    'accession': '@CHEMICAL_Retinoids'},
#   'text': 'retinoids',
#   'locations': [{'offset': 942, 'length': 9}]},
#  {'id': '37',
#   'infons': {'identifier': 'MESH:D008055',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008055'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008055',
#    'biotype': 'chemical',
#    'name': 'Lipids',
#    'accession': '@CHEMICAL_Lipids'},
#   'text': 'lipid',
#   'locations': [{'offset': 978, 'length': 5}]},
#  {'id': '38',
#   'infons': {'identifier': 'MESH:C099555',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C099555'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C099555',
#    'biotype': 'chemical',
#    'name': 'CD 437',
#    'accession': '@CHEMICAL_CD_437'},
#   'text': 'CD437',
#   'locations': [{'offset': 1052, 'length': 5}]},
#  {'id': '39',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'cytotoxicity',
#   'locations': [{'offset': 1123, 'length': 12}]},
#  {'id': '40',
#   'infons': {'identifier': 'MESH:C099555',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C099555'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C099555',
#    'biotype': 'chemical',
#    'name': 'CD 437',
#    'accession': '@CHEMICAL_CD_437'},
#   'text': 'CD437',
#   'locations': [{'offset': 1150, 'length': 5}]},
#  {'id': '41',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 1204, 'length': 10}]},
#  {'id': '42',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mouse',
#   'locations': [{'offset': 1251, 'length': 5}]},
#  {'id': '43',
#   'infons': {'identifier': 'MESH:D013203',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D013203'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013203',
#    'biotype': 'disease',
#    'name': 'Staphylococcal Infections',
#    'accession': '@DISEASE_Staphylococcal_Infections'},
#   'text': 'MRSA infection',
#   'locations': [{'offset': 1274, 'length': 14}]},
#  {'id': '44',
#   'infons': {'identifier': 'MESH:D012176',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012176'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012176',
#    'biotype': 'chemical',
#    'name': 'Retinoids',
#    'accession': '@CHEMICAL_Retinoids'},
#   'text': 'retinoids',
#   'locations': [{'offset': 1343, 'length': 9}]},
#  {'id': '45',
#   'infons': {'identifier': 'MESH:D001424',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D001424'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D001424',
#    'biotype': 'disease',
#    'name': 'Bacterial Infections',
#    'accession': '@DISEASE_Bacterial_Infections'},
#   'text': 'bacterial infections',
#   'locations': [{'offset': 1447, 'length': 20}]}]
# 32499514
# [{'id': '19281',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'toxicity',
#   'locations': [{'offset': 1589, 'length': 8}]},
#  {'id': '19282',
#   'infons': {'identifier': '287',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [287],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 287,
#    'biotype': 'species',
#    'name': '287',
#    'accession': None},
#   'text': 'Pseudomonas aeruginosa',
#   'locations': [{'offset': 1558, 'length': 22}]},
#  {'id': '19283',
#   'infons': {'identifier': 'MESH:D006461',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D006461'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006461',
#    'biotype': 'disease',
#    'name': 'Hemolysis',
#    'accession': '@DISEASE_Hemolysis'},
#   'text': 'hemolytic',
#   'locations': [{'offset': 1415, 'length': 9}]},
#  {'id': '19284',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'lipopolysaccharide',
#   'locations': [{'offset': 1852, 'length': 18}]},
#  {'id': '19285',
#   'infons': {'identifier': 'MESH:C014308',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C014308'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C014308',
#    'biotype': 'chemical',
#    'name': "adenosine 5'-phosphorothioate",
#    'accession': "@CHEMICAL_adenosine_5'_phosphorothioate"},
#   'text': 'AMPs',
#   'locations': [{'offset': 188, 'length': 4}]},
#  {'id': '19286',
#   'infons': {'identifier': 'MESH:C014308',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C014308'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C014308',
#    'biotype': 'chemical',
#    'name': "adenosine 5'-phosphorothioate",
#    'accession': "@CHEMICAL_adenosine_5'_phosphorothioate"},
#   'text': 'AMPs',
#   'locations': [{'offset': 349, 'length': 4}]},
#  {'id': '19287',
#   'infons': {'identifier': 'MESH:D007249',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007249'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007249',
#    'biotype': 'disease',
#    'name': 'Inflammation',
#    'accession': '@DISEASE_Inflammation'},
#   'text': 'inflammatory',
#   'locations': [{'offset': 1826, 'length': 12}]},
#  {'id': '19288',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infections',
#   'locations': [{'offset': 282, 'length': 10}]},
#  {'id': '19289',
#   'infons': {'identifier': 'MESH:D000089882',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000089882'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000089882',
#    'biotype': 'chemical',
#    'name': 'Antimicrobial Peptides',
#    'accession': '@CHEMICAL_Antimicrobial_Peptides'},
#   'text': 'Antimicrobial peptides',
#   'locations': [{'offset': 164, 'length': 22}]},
#  {'id': '19290',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 1872, 'length': 3}]},
#  {'id': '19291',
#   'infons': {'identifier': 'MESH:D006461',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D006461'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006461',
#    'biotype': 'disease',
#    'name': 'Hemolysis',
#    'accession': '@DISEASE_Hemolysis'},
#   'text': 'hemolytic',
#   'locations': [{'offset': 1218, 'length': 9}]},
#  {'id': '19292',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 1925, 'length': 3}]}]
# 28671682
# [{'id': '8',
#   'infons': {'identifier': 'MESH:C082735',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082735'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082735',
#    'biotype': 'chemical',
#    'name': 'azetidine',
#    'accession': '@CHEMICAL_azetidine'},
#   'text': 'azetidine',
#   'locations': [{'offset': 466, 'length': 9}]},
#  {'id': '9',
#   'infons': {'identifier': 'MESH:C000622376',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C000622376'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C000622376',
#    'biotype': 'chemical',
#    'name': 'BRD4592',
#    'accession': '@CHEMICAL_BRD4592'},
#   'text': 'BRD4592',
#   'locations': [{'offset': 488, 'length': 7}]},
#  {'id': '10',
#   'infons': {'identifier': '1773',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1773],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1773,
#    'biotype': 'species',
#    'name': '1773',
#    'accession': None},
#   'text': 'Mycobacterium tuberculosis',
#   'locations': [{'offset': 508, 'length': 26}]},
#  {'id': '11',
#   'infons': {'identifier': '1773',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1773],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1773,
#    'biotype': 'species',
#    'name': '1773',
#    'accession': None},
#   'text': 'Mtb',
#   'locations': [{'offset': 536, 'length': 3}]},
#  {'id': '12',
#   'infons': {'identifier': '1773',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1773],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1773,
#    'biotype': 'species',
#    'name': '1773',
#    'accession': None},
#   'text': 'Mtb',
#   'locations': [{'offset': 917, 'length': 3}]},
#  {'id': '13',
#   'infons': {'identifier': '1781',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1781],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1781,
#    'biotype': 'species',
#    'name': '1781',
#    'accession': None},
#   'text': 'Mycobacterium marinum',
#   'locations': [{'offset': 925, 'length': 21}]}]
# 34707295
# [{'id': '25',
#   'infons': {'identifier': '629395',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [629395],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 629395,
#    'biotype': 'species',
#    'name': '629395',
#    'accession': None},
#   'text': 'bacteria',
#   'locations': [{'offset': 139, 'length': 8}]},
#  {'id': '26',
#   'infons': {'identifier': 'MESH:D060467',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D060467'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D060467',
#    'biotype': 'disease',
#    'name': 'Disease Resistance',
#    'accession': '@DISEASE_Disease_Resistance'},
#   'text': 'resistance',
#   'locations': [{'offset': 391, 'length': 10}]},
#  {'id': '27',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'oxepanoproline',
#   'locations': [{'offset': 771, 'length': 14}]},
#  {'id': '28',
#   'infons': {'identifier': 'MESH:D002981',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002981'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002981',
#    'biotype': 'chemical',
#    'name': 'Clindamycin',
#    'accession': '@CHEMICAL_Clindamycin'},
#   'text': 'clindamycin',
#   'locations': [{'offset': 844, 'length': 11}]},
#  {'id': '29',
#   'infons': {'identifier': 'MESH:C000722214',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C000722214'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C000722214',
#    'biotype': 'chemical',
#    'name': 'iboxamycin',
#    'accession': '@CHEMICAL_iboxamycin'},
#   'text': 'iboxamycin',
#   'locations': [{'offset': 943, 'length': 10}]},
#  {'id': '30',
#   'infons': {'identifier': 'MESH:C000722214',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C000722214'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C000722214',
#    'biotype': 'chemical',
#    'name': 'iboxamycin',
#    'accession': '@CHEMICAL_iboxamycin'},
#   'text': 'Iboxamycin',
#   'locations': [{'offset': 955, 'length': 10}]},
#  {'id': '31',
#   'infons': {'type': 'Disease',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'disease'},
#   'text': 'ESKAPE',
#   'locations': [{'offset': 987, 'length': 6}]},
#  {'id': '32',
#   'infons': {'identifier': '20340',
#    'type': 'Gene',
#    'ncbi_homologene': '7533',
#    'valid': True,
#    'normalized': [20340],
#    'database': 'ncbi_gene',
#    'normalized_id': 20340,
#    'biotype': 'gene',
#    'name': 'Glg1',
#    'accession': '@GENE_GLG1'},
#   'text': 'Cfr',
#   'locations': [{'offset': 1041, 'length': 3}]},
#  {'id': '33',
#   'infons': {'identifier': 'MESH:D060467',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D060467'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D060467',
#    'biotype': 'disease',
#    'name': 'Disease Resistance',
#    'accession': '@DISEASE_Disease_Resistance'},
#   'text': 'resistance',
#   'locations': [{'offset': 1116, 'length': 10}]},
#  {'id': '34',
#   'infons': {'identifier': 'MESH:D018942',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D018942'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D018942',
#    'biotype': 'chemical',
#    'name': 'Macrolides',
#    'accession': '@CHEMICAL_Macrolides'},
#   'text': 'macrolides',
#   'locations': [{'offset': 1212, 'length': 10}]},
#  {'id': '35',
#   'infons': {'identifier': 'MESH:D055231',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D055231'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D055231',
#    'biotype': 'chemical',
#    'name': 'Lincosamides',
#    'accession': '@CHEMICAL_Lincosamides'},
#   'text': 'lincosamides',
#   'locations': [{'offset': 1224, 'length': 12}]},
#  {'id': '36',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'phenicols',
#   'locations': [{'offset': 1238, 'length': 9}]},
#  {'id': '37',
#   'infons': {'identifier': 'MESH:D023303',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D023303'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D023303',
#    'biotype': 'chemical',
#    'name': 'Oxazolidinones',
#    'accession': '@CHEMICAL_Oxazolidinones'},
#   'text': 'oxazolidinones',
#   'locations': [{'offset': 1249, 'length': 14}]},
#  {'id': '38',
#   'infons': {'identifier': 'MESH:C004262',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C004262'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C004262',
#    'biotype': 'chemical',
#    'name': 'pleuromutilin',
#    'accession': '@CHEMICAL_pleuromutilin'},
#   'text': 'pleuromutilins',
#   'locations': [{'offset': 1265, 'length': 14}]},
#  {'id': '39',
#   'infons': {'identifier': 'MESH:D025361',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D025361'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D025361',
#    'biotype': 'chemical',
#    'name': 'Streptogramins',
#    'accession': '@CHEMICAL_Streptogramins'},
#   'text': 'streptogramins',
#   'locations': [{'offset': 1284, 'length': 14}]},
#  {'id': '40',
#   'infons': {'identifier': 'MESH:C000722214',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C000722214'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C000722214',
#    'biotype': 'chemical',
#    'name': 'iboxamycin',
#    'accession': '@CHEMICAL_iboxamycin'},
#   'text': 'iboxamycin',
#   'locations': [{'offset': 1334, 'length': 10}]},
#  {'id': '41',
#   'infons': {'identifier': 'MESH:D001424',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D001424'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D001424',
#    'biotype': 'disease',
#    'name': 'Bacterial Infections',
#    'accession': '@DISEASE_Bacterial_Infections'},
#   'text': 'bacterial',
#   'locations': [{'offset': 1372, 'length': 9}]},
#  {'id': '42',
#   'infons': {'identifier': 'MESH:C000722214',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C000722214'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C000722214',
#    'biotype': 'chemical',
#    'name': 'iboxamycin',
#    'accession': '@CHEMICAL_iboxamycin'},
#   'text': 'Iboxamycin',
#   'locations': [{'offset': 1582, 'length': 10}]},
#  {'id': '43',
#   'infons': {'identifier': 'MESH:D001424',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D001424'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D001424',
#    'biotype': 'disease',
#    'name': 'Bacterial Infections',
#    'accession': '@DISEASE_Bacterial_Infections'},
#   'text': 'bacterial infections',
#   'locations': [{'offset': 1685, 'length': 20}]},
#  {'id': '44',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mice',
#   'locations': [{'offset': 1709, 'length': 4}]},
#  {'id': '45',
#   'infons': {'identifier': 'MESH:D060467',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D060467'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D060467',
#    'biotype': 'disease',
#    'name': 'Disease Resistance',
#    'accession': '@DISEASE_Disease_Resistance'},
#   'text': 'resistance',
#   'locations': [{'offset': 1815, 'length': 10}]}]
# 35338128
# [{'id': '13855',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'toxicity',
#   'locations': [{'offset': 515, 'length': 8}]},
#  {'id': '13856',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'polymyxin lipopeptide antibiotics',
#   'locations': [{'offset': 205, 'length': 33}]},
#  {'id': '13857',
#   'infons': {'identifier': '287',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [287],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 287,
#    'biotype': 'species',
#    'name': '287',
#    'accession': None},
#   'text': 'Pseudomonas aeruginosa',
#   'locations': [{'offset': 1142, 'length': 22}]},
#  {'id': '13858',
#   'infons': {'identifier': 'MESH:D012141',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D012141'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012141',
#    'biotype': 'disease',
#    'name': 'Respiratory Tract Infections',
#    'accession': '@DISEASE_Respiratory_Tract_Infections'},
#   'text': 'lung infections',
#   'locations': [{'offset': 1089, 'length': 15}]},
#  {'id': '13859',
#   'infons': {'type': 'Disease',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'disease'},
#   'text': 'nephrotoxicity',
#   'locations': [{'offset': 493, 'length': 14}]},
#  {'id': '13860',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'F365',
#   'locations': [{'offset': 1032, 'length': 4}]},
#  {'id': '13861',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'toxicity',
#   'locations': [{'offset': 868, 'length': 8}]},
#  {'id': '13862',
#   'infons': {'identifier': 'MESH:D055666',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D055666'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D055666',
#    'biotype': 'chemical',
#    'name': 'Lipopeptides',
#    'accession': '@CHEMICAL_Lipopeptides'},
#   'text': 'lipopeptide',
#   'locations': [{'offset': 904, 'length': 11}]},
#  {'id': '13863',
#   'infons': {'identifier': '573',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [573],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 573,
#    'biotype': 'species',
#    'name': '573',
#    'accession': None},
#   'text': 'Klebsiella pneumoniae',
#   'locations': [{'offset': 1194, 'length': 21}]},
#  {'id': '13864',
#   'infons': {'identifier': '470',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [470],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 470,
#    'biotype': 'species',
#    'name': '470',
#    'accession': None},
#   'text': 'Acinetobacter baumannii',
#   'locations': [{'offset': 1166, 'length': 23}]},
#  {'id': '13865',
#   'infons': {'identifier': 'MESH:D012141',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D012141'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012141',
#    'biotype': 'disease',
#    'name': 'Respiratory Tract Infections',
#    'accession': '@DISEASE_Respiratory_Tract_Infections'},
#   'text': 'pulmonary infections',
#   'locations': [{'offset': 614, 'length': 20}]},
#  {'id': '13866',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'QPX9003',
#   'locations': [{'offset': 1038, 'length': 7}]}]
# 24226776
# [{'id': '14',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infections',
#   'locations': [{'offset': 84, 'length': 10}]},
#  {'id': '15',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infection',
#   'locations': [{'offset': 562, 'length': 9}]},
#  {'id': '16',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infection',
#   'locations': [{'offset': 604, 'length': 9}]},
#  {'id': '17',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'acyldepsipeptide antibiotic',
#   'locations': [{'offset': 728, 'length': 27}]},
#  {'id': '18',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'ADEP4',
#   'locations': [{'offset': 757, 'length': 5}]},
#  {'id': '19',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'ADEP4',
#   'locations': [{'offset': 1071, 'length': 5}]},
#  {'id': '20',
#   'infons': {'identifier': 'MESH:D012293',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012293'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012293',
#    'biotype': 'chemical',
#    'name': 'Rifampin',
#    'accession': '@CHEMICAL_Rifampin'},
#   'text': 'rifampicin',
#   'locations': [{'offset': 1082, 'length': 10}]},
#  {'id': '21',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 1126, 'length': 21}]},
#  {'id': '22',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mouse',
#   'locations': [{'offset': 1175, 'length': 5}]},
#  {'id': '23',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infection',
#   'locations': [{'offset': 1200, 'length': 9}]},
#  {'id': '24',
#   'infons': {'type': 'Disease',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'disease'},
#   'text': 'biofilm',
#   'locations': [{'offset': 1372, 'length': 7}]},
#  {'id': '25',
#   'infons': {'identifier': 'MESH:D007239',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007239',
#    'biotype': 'disease',
#    'name': 'Infections',
#    'accession': '@DISEASE_Infections'},
#   'text': 'infections',
#   'locations': [{'offset': 1496, 'length': 10}]}]
# 30356080
# [{'id': '22',
#   'infons': {'identifier': '1931',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1931],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1931,
#    'biotype': 'species',
#    'name': '1931',
#    'accession': None},
#   'text': 'Streptomyces sp.',
#   'locations': [{'offset': 186, 'length': 16}]},
#  {'id': '23',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'ICN19',
#   'locations': [{'offset': 203, 'length': 5}]},
#  {'id': '24',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Ala-geninthiocin',
#   'locations': [{'offset': 218, 'length': 16}]},
#  {'id': '25',
#   'infons': {'identifier': 'MESH:C089890',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C089890'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C089890',
#    'biotype': 'chemical',
#    'name': 'geninthiocin',
#    'accession': '@CHEMICAL_geninthiocin'},
#   'text': 'geninthiocin',
#   'locations': [{'offset': 269, 'length': 12}]},
#  {'id': '26',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Val-geninthiocin',
#   'locations': [{'offset': 290, 'length': 16}]},
#  {'id': '27',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'indolocarbazole',
#   'locations': [{'offset': 319, 'length': 15}]},
#  {'id': '28',
#   'infons': {'identifier': 'MESH:D019311',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D019311'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D019311',
#    'biotype': 'chemical',
#    'name': 'Staurosporine',
#    'accession': '@CHEMICAL_Staurosporine'},
#   'text': 'staurosporine',
#   'locations': [{'offset': 335, 'length': 13}]},
#  {'id': '29',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 625, 'length': 21}]},
#  {'id': '30',
#   'infons': {'identifier': '1423',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1423],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1423,
#    'biotype': 'species',
#    'name': '1423',
#    'accession': None},
#   'text': 'Bacillus subtilis',
#   'locations': [{'offset': 648, 'length': 17}]},
#  {'id': '31',
#   'infons': {'identifier': '1772',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1772],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1772,
#    'biotype': 'species',
#    'name': '1772',
#    'accession': None},
#   'text': 'Mycobacterium smegmatis',
#   'locations': [{'offset': 667, 'length': 23}]},
#  {'id': '32',
#   'infons': {'identifier': '1270',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1270],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1270,
#    'biotype': 'species',
#    'name': '1270',
#    'accession': None},
#   'text': 'Micrococcus luteus',
#   'locations': [{'offset': 696, 'length': 18}]},
#  {'id': '33',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'cytotoxicity',
#   'locations': [{'offset': 727, 'length': 12}]},
#  {'id': '34',
#   'infons': {'identifier': 'CVCL:0023',
#    'type': 'CellLine',
#    'valid': True,
#    'normalized': ['0023'],
#    'database': 'cvcl',
#    'normalized_id': '0023',
#    'biotype': 'cellline',
#    'name': '0023',
#    'accession': None},
#   'text': 'A549',
#   'locations': [{'offset': 748, 'length': 4}]},
#  {'id': '35',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'human lung carcinoma',
#   'locations': [{'offset': 753, 'length': 20}]}]
# 31451755
# [{'id': '13',
#   'infons': {'identifier': '629395',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [629395],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 629395,
#    'biotype': 'species',
#    'name': '629395',
#    'accession': None},
#   'text': 'bacteria',
#   'locations': [{'offset': 113, 'length': 8}]},
#  {'id': '14',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'Albicidin',
#   'locations': [{'offset': 226, 'length': 9}]},
#  {'id': '15',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'sugarcane',
#   'locations': [{'offset': 252, 'length': 9}]},
#  {'id': '16',
#   'infons': {'identifier': '29447',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [29447],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 29447,
#    'biotype': 'species',
#    'name': '29447',
#    'accession': None},
#   'text': 'Xanthomonas albilineans',
#   'locations': [{'offset': 271, 'length': 23}]},
#  {'id': '17',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'Albicidin',
#   'locations': [{'offset': 406, 'length': 9}]},
#  {'id': '18',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 540, 'length': 10}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'albicidin',
#   'locations': [{'offset': 580, 'length': 9}]},
#  {'id': '20',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'albicidin',
#   'locations': [{'offset': 699, 'length': 9}]},
#  {'id': '21',
#   'infons': {'identifier': 'MESH:D013206',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D013206'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013206',
#    'biotype': 'disease',
#    'name': 'Staphylococcal Scalded Skin Syndrome',
#    'accession': '@DISEASE_Staphylococcal_Scalded_Skin_Syndrome'},
#   'text': 'sugarcane leaf-scald disease',
#   'locations': [{'offset': 713, 'length': 28}]},
#  {'id': '22',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'albicidin',
#   'locations': [{'offset': 815, 'length': 9}]},
#  {'id': '23',
#   'infons': {'identifier': 'MESH:C046156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C046156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C046156',
#    'biotype': 'chemical',
#    'name': 'albicidin',
#    'accession': '@CHEMICAL_albicidin'},
#   'text': 'albicidin',
#   'locations': [{'offset': 899, 'length': 9}]}]
# 33654250
# [{'id': '17',
#   'infons': {'identifier': 'MESH:D006679',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D006679'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006679',
#    'biotype': 'disease',
#    'name': 'HIV Seropositivity',
#    'accession': '@DISEASE_HIV_Seropositivity'},
#   'text': 'anti-mannheimiosis',
#   'locations': [{'offset': 137, 'length': 18}]},
#  {'id': '18',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'aldsulfin',
#   'locations': [{'offset': 163, 'length': 9}]},
#  {'id': '19',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Lasiodiplodia pseudotheobromae FKI-4499',
#   'locations': [{'offset': 222, 'length': 39}]},
#  {'id': '20',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'lasiodipline C',
#   'locations': [{'offset': 295, 'length': 14}]},
#  {'id': '21',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'aldsulfin',
#   'locations': [{'offset': 374, 'length': 9}]},
#  {'id': '22',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'epithiodiketopiperazine',
#   'locations': [{'offset': 452, 'length': 23}]},
#  {'id': '23',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Aldsulfin',
#   'locations': [{'offset': 528, 'length': 9}]},
#  {'id': '24',
#   'infons': {'identifier': '75985',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [75985],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 75985,
#    'biotype': 'species',
#    'name': '75985',
#    'accession': None},
#   'text': 'Mannheimia haemolytica',
#   'locations': [{'offset': 576, 'length': 22}]},
#  {'id': '25',
#   'infons': {'identifier': '747',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [747],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 747,
#    'biotype': 'species',
#    'name': '747',
#    'accession': None},
#   'text': 'Pasteurella multocida',
#   'locations': [{'offset': 603, 'length': 21}]}]
# 35715695
# [{'id': '22801',
#   'infons': {'identifier': '1785',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1785],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1785,
#    'biotype': 'species',
#    'name': '1785',
#    'accession': None},
#   'text': 'Mycobacterium sp',
#   'locations': [{'offset': 1189, 'length': 16}]},
#  {'id': '22802',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Pyrimidomycin',
#   'locations': [{'offset': 1327, 'length': 13}]},
#  {'id': '22803',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'PSAA01',
#   'locations': [{'offset': 727, 'length': 6}]},
#  {'id': '22804',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'SM02',
#   'locations': [{'offset': 891, 'length': 4}]},
#  {'id': '22805',
#   'infons': {'identifier': '9606',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [9606],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 9606,
#    'biotype': 'species',
#    'name': '9606',
#    'accession': None},
#   'text': 'human',
#   'locations': [{'offset': 1584, 'length': 5}]},
#  {'id': '22806',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. aureus',
#   'locations': [{'offset': 1404, 'length': 9}]},
#  {'id': '22807',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'pyrimidomycin',
#   'locations': [{'offset': 1428, 'length': 13}]},
# ...
#   'text': 'venturicidin A',
#   'locations': [{'offset': 588, 'length': 14}]},
#  {'id': '2999',
#   'infons': {'identifier': 'MESH:D000617',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000617'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000617',
#    'biotype': 'chemical',
#    'name': 'Aminoglycosides',
#    'accession': '@CHEMICAL_Aminoglycosides'},
#   'text': 'aminoglycoside',
#   'locations': [{'offset': 633, 'length': 14}]},
#  {'id': '3000',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'aminoglycoside antibiotics',
#   'locations': [{'offset': 1471, 'length': 26}]},
#  {'id': '3001',
#   'infons': {'identifier': 'MESH:D003141',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D003141'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D003141',
#    'biotype': 'disease',
#    'name': 'Communicable Diseases',
#    'accession': '@DISEASE_Communicable_Diseases'},
#   'text': 'infectious diseases',
#   'locations': [{'offset': 210, 'length': 19}]},
#  {'id': '3002',
#   'infons': {'identifier': 'MESH:D000255',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000255'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000255',
#    'biotype': 'chemical',
#    'name': 'Adenosine Triphosphate',
#    'accession': '@CHEMICAL_Adenosine_Triphosphate'},
#   'text': 'ATP',
#   'locations': [{'offset': 1001, 'length': 3}]},
#  {'id': '3003',
#   'infons': {'identifier': '287',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [287],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 287,
#    'biotype': 'species',
#    'name': '287',
#    'accession': None},
#   'text': 'Pseudomonas aeruginosa',
#   'locations': [{'offset': 753, 'length': 22}]},
#  {'id': '3004',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. aureus',
#   'locations': [{'offset': 892, 'length': 9}]},
#  {'id': '3005',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 659, 'length': 10}]},
#  {'id': '3006',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MRSA',
#   'locations': [{'offset': 1319, 'length': 4}]},
#  {'id': '3007',
#   'infons': {'identifier': 'MESH:C068161',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C068161'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C068161',
#    'biotype': 'chemical',
#    'name': 'venturicidin A',
#    'accession': '@CHEMICAL_venturicidin_A'},
#   'text': 'VentA',
#   'locations': [{'offset': 604, 'length': 5}]},
#  {'id': '3008',
#   'infons': {'identifier': '1352',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1352],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1352,
#    'biotype': 'species',
#    'name': '1352',
#    'accession': None},
#   'text': 'Enterococcus',
#   'locations': [{'offset': 735, 'length': 12}]},
#  {'id': '3009',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 870, 'length': 11}]},
#  {'id': '3010',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 937, 'length': 10}]},
#  {'id': '3011',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MRSA',
#   'locations': [{'offset': 903, 'length': 4}]},
#  {'id': '3012',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 1213, 'length': 10}]},
#  {'id': '3013',
#   'infons': {'identifier': 'MESH:C068161',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C068161'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C068161',
#    'biotype': 'chemical',
#    'name': 'venturicidin A',
#    'accession': '@CHEMICAL_venturicidin_A'},
#   'text': 'VentA',
#   'locations': [{'offset': 1018, 'length': 5}]},
#  {'id': '3014',
#   'infons': {'identifier': 'MESH:C068161',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C068161'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C068161',
#    'biotype': 'chemical',
#    'name': 'venturicidin A',
#    'accession': '@CHEMICAL_venturicidin_A'},
#   'text': 'VentA',
#   'locations': [{'offset': 824, 'length': 5}]},
#  {'id': '3015',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus',
#   'locations': [{'offset': 719, 'length': 14}]},
#  {'id': '3016',
#   'infons': {'identifier': 'MESH:D005839',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D005839'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D005839',
#    'biotype': 'chemical',
#    'name': 'Gentamicins',
#    'accession': '@CHEMICAL_Gentamicins'},
#   'text': 'gentamicin',
#   'locations': [{'offset': 809, 'length': 10}]}]
# 20057515
# [{'id': '19',
#   'infons': {'type': 'Gene',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'gene'},
#   'text': 'WalR',
#   'locations': [{'offset': 119, 'length': 4}]},
#  {'id': '20',
#   'infons': {'identifier': '1423',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1423],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1423,
#    'biotype': 'species',
#    'name': '1423',
#    'accession': None},
#   'text': 'Bacillus subtilis',
#   'locations': [{'offset': 267, 'length': 17}]},
#  {'id': '21',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 289, 'length': 21}]},
#  {'id': '22',
#   'infons': {'identifier': '1931',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1931],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1931,
#    'biotype': 'species',
#    'name': '1931',
#    'accession': None},
#   'text': 'Streptomyces sp.',
#   'locations': [{'offset': 439, 'length': 16}]},
#  {'id': '23',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'walkmycin A, B and C',
#   'locations': [{'offset': 488, 'length': 20}]},
#  {'id': '24',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MK632-100F11',
#   'locations': [{'offset': 540, 'length': 12}]},
#  {'id': '25',
#   'infons': {'identifier': 'MESH:D012822',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012822'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012822',
#    'biotype': 'chemical',
#    'name': 'Silicon Dioxide',
#    'accession': '@CHEMICAL_Silicon_Dioxide'},
#   'text': 'silica',
#   'locations': [{'offset': 574, 'length': 6}]},
#  {'id': '26',
#   'infons': {'identifier': 'MESH:C548104',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C548104'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C548104',
#    'biotype': 'chemical',
#    'name': 'walkmycin B',
#    'accession': '@CHEMICAL_walkmycin_B'},
#   'text': 'walkmycin B',
#   'locations': [{'offset': 677, 'length': 11}]},
#  {'id': '27',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'di-anthracenone',
#   'locations': [{'offset': 711, 'length': 15}]},
#  {'id': '28',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'C(44)H(44)Cl(2)O(14)',
#   'locations': [{'offset': 728, 'length': 20}]},
#  {'id': '29',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'BE40665A.',
#   'locations': [{'offset': 777, 'length': 9}]},
#  {'id': '30',
#   'infons': {'identifier': 'MESH:C548104',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C548104'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C548104',
#    'biotype': 'chemical',
#    'name': 'walkmycin B',
#    'accession': '@CHEMICAL_walkmycin_B'},
#   'text': 'walkmycin B',
#   'locations': [{'offset': 795, 'length': 11}]},
#  {'id': '31',
#   'infons': {'identifier': '1423',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1423],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1423,
#    'biotype': 'species',
#    'name': '1423',
#    'accession': None},
#   'text': 'B. subtilis',
#   'locations': [{'offset': 815, 'length': 11}]},
#  {'id': '32',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'S. aureus',
#   'locations': [{'offset': 831, 'length': 9}]},
#  {'id': '33',
#   'infons': {'identifier': 'MESH:C548104',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C548104'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C548104',
#    'biotype': 'chemical',
#    'name': 'walkmycin B',
#    'accession': '@CHEMICAL_walkmycin_B'},
#   'text': 'walkmycin B',
#   'locations': [{'offset': 992, 'length': 11}]},
#  {'id': '34',
#   'infons': {'identifier': '1423',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1423],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1423,
#    'biotype': 'species',
#    'name': '1423',
#    'accession': None},
#   'text': 'B. subtilis',
#   'locations': [{'offset': 1146, 'length': 11}]},
#  {'id': '35',
#   'infons': {'identifier': 'MESH:C548104',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C548104'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C548104',
#    'biotype': 'chemical',
#    'name': 'walkmycin B',
#    'accession': '@CHEMICAL_walkmycin_B'},
#   'text': 'walkmycin B',
#   'locations': [{'offset': 1191, 'length': 11}]}]
# 36071214
# [{'id': '10652',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 783, 'length': 11}]},
#  {'id': '10653',
#   'infons': {'identifier': '1213861',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1213861],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1213861,
#    'biotype': 'species',
#    'name': '1213861',
#    'accession': None},
#   'text': 'Actinocrispum wychmicini',
#   'locations': [{'offset': 313, 'length': 24}]},
#  {'id': '10654',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'spirotetronates',
#   'locations': [{'offset': 372, 'length': 15}]},
#  {'id': '10655',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'wychimicins A-D',
#   'locations': [{'offset': 234, 'length': 15}]},
#  {'id': '10656',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MI503-AF4',
#   'locations': [{'offset': 345, 'length': 9}]},
#  {'id': '10657',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Wychimicins',
#   'locations': [{'offset': 356, 'length': 11}]},
#  {'id': '10658',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 146, 'length': 11}]},
#  {'id': '10659',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Wychimicins',
#   'locations': [{'offset': 701, 'length': 11}]},
#  {'id': '10660',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 168, 'length': 21}]},
#  {'id': '10661',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'spirocarbon C-25',
#   'locations': [{'offset': 677, 'length': 16}]},
#  {'id': '10662',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 805, 'length': 21}]},
#  {'id': '10663',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'beta-d-xylo-hexopyranose',
#   'locations': [{'offset': 459, 'length': 24}]},
#  {'id': '10664',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'trans-decalin',
#   'locations': [{'offset': 441, 'length': 13}]}]
# 33741965
# [{'id': '9349',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mice',
#   'locations': [{'offset': 680, 'length': 4}]},
#  {'id': '9350',
#   'infons': {'identifier': 'MESH:D006069',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D006069'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006069',
#    'biotype': 'disease',
#    'name': 'Gonorrhea',
#    'accession': '@DISEASE_Gonorrhea'},
#   'text': 'Neisseria gonorrhoeae infection',
#   'locations': [{'offset': 645, 'length': 31}]},
#  {'id': '9351',
#   'infons': {'identifier': '9606',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [9606],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 9606,
#    'biotype': 'species',
#    'name': '9606',
#    'accession': None},
#   'text': 'humans',
#   'locations': [{'offset': 310, 'length': 6}]},
#  {'id': '9352',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'acylaminooxadiazoles',
#   'locations': [{'offset': 780, 'length': 20}]},
#  {'id': '9353',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'MBX-4132',
#   'locations': [{'offset': 598, 'length': 8}]},
#  {'id': '9354',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'acylaminooxadiazoles',
#   'locations': [{'offset': 566, 'length': 20}]},
#  {'id': '9355',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'acylaminooxadiazoles',
#   'locations': [{'offset': 370, 'length': 20}]}]

# %%
pos_df[ pos_df['PubTator'].str.len() < 1 ]
# Out:
#                                                 Title      PMID       Targets  \
# 41  Identification and evaluation of a potent nove...  21730979   ['NU-6027']
# 48  Inhibition of translation termination by the a...  36997647  ['Drosocin']
#
#                                              Abstract PubTator
# 41  The ataxia telangiectasia mutated and Rad3-rel...       []
# 48  The proline-rich antimicrobial peptide (PrAMP)...       []

# %%
def pubtator_process(id):

    url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/export/biocjson?pmids={id}&full=true"
    res = requests.get(url)
    print(id)
    res_js = json.loads(res.content)['PubTator3']

    # Only working with abstracts
    abstract_js = [js for js in res_js[0]['passages'] if js['infons']['type'] == 'abstract']

    pubt_annot = [js['annotations'] for js in abstract_js]
    pubt_annot = sum(pubt_annot, [])
    #display(pubt_annot)
    pubt_res = pubtator_generate_struct(pubt_annot)

    time.sleep(0.6)

    return sorted(pubt_res, key=lambda d: d['location']['start'])

# %%
pos_df
# Out:
#                                                 Title      PMID  \
# 0   2-Pyrazol-1-yl-thiazole derivatives as novel h...  31358913
# 1   A choline binding polypeptide of LytA inhibits...  30127421
# 2   A naturally inspired antibiotic to target mult...  34987225
# 3   A new class of synthetic retinoid antibiotics ...  29590091
# 4   A novel, rationally designed, hybrid antimicro...  32499514
# ..                                                ...       ...
# 75  Total synthesis and antimicrobial evaluation o...  30181560
# 76  Venturicidin A, A Membrane-active Natural Prod...  32424122
# 77  Walkmycin B targets WalK (YycG), a histidine k...  20057515
# 78  Wychimicins, a new class of spirotetronate pol...  36071214
# 79  trans-Translation inhibitors bind to a novel s...  33741965
#
#                                               Targets  \
# 0                      ['2-(pyrazol-1-yl)- thiazole']
# 1                                            ['ChBp']
# 2                                       ['Macolacin']
# 3                                 ['CD1530', 'CD437']
# 4                                           ['PA-13']
# ..                                                ...
# 75  ['Albomycin', 'albomycin delta 2', 'grisein', ...
# 76                                 ['Venturicidin A']
# 77                                    ['Walkmycin B']
# 78                                     ['Wychimicin']
# 79                                       ['MBX-4132']
#
#                                              Abstract  \
# 0   The present report describes our efforts to id...
# 1   Streptococcus pneumoniae is a pathogen that ma...
# 2   Gram-negative bacteria are responsible for an ...
# 3   A challenge in the treatment of Staphylococcus...
# 4   Antimicrobial peptides (AMPs) are promising al...
# ..                                                ...
# 75  Development of effective antimicrobial agents ...
# 76  Despite the remarkable advances due to the dis...
# 77  The WalK (a histidine kinase)/WalR (a response...
# 78  In the course of our screening program for new...
# 79  Bacterial ribosome rescue pathways that remove...
#
#                                              PubTator
# 0   [{'text': '2-pyrazol-1-yl-thiazole', 'location...
# 1   [{'text': 'choline', 'location': {'start': 906...
# 2   [{'text': 'colistin3', 'location': {'start': 4...
# 3   [{'text': 'methicillin', 'location': {'start':...
# 4   [{'text': 'lipopolysaccharide', 'location': {'...
# ..                                                ...
# 75  [{'text': 'peptidylnucleoside', 'location': {'...
# 76  [{'text': 'VentA', 'location': {'start': 1452,...
# 77  [{'text': 'walkmycin A, B and C', 'location': ...
# 78  [{'text': 'methicillin', 'location': {'start':...
# 79  [{'text': 'acylaminooxadiazoles', 'location': ...
#
# [80 rows x 5 columns]

# %%
def collapse_pubtator(row):
    texts = []
    for d in row:
        texts.append(d['text'])
    return list(set(texts))

pos_df['PubTator_simplified'] = pos_df['PubTator'].apply(collapse_pubtator)
pos_df
# Out:
#                                                 Title      PMID  \
# 0   2-Pyrazol-1-yl-thiazole derivatives as novel h...  31358913
# 1   A choline binding polypeptide of LytA inhibits...  30127421
# 2   A naturally inspired antibiotic to target mult...  34987225
# 3   A new class of synthetic retinoid antibiotics ...  29590091
# 4   A novel, rationally designed, hybrid antimicro...  32499514
# ..                                                ...       ...
# 75  Total synthesis and antimicrobial evaluation o...  30181560
# 76  Venturicidin A, A Membrane-active Natural Prod...  32424122
# 77  Walkmycin B targets WalK (YycG), a histidine k...  20057515
# 78  Wychimicins, a new class of spirotetronate pol...  36071214
# 79  trans-Translation inhibitors bind to a novel s...  33741965
#
#                                               Targets  \
# 0                      ['2-(pyrazol-1-yl)- thiazole']
# 1                                            ['ChBp']
# 2                                       ['Macolacin']
# 3                                 ['CD1530', 'CD437']
# 4                                           ['PA-13']
# ..                                                ...
# 75  ['Albomycin', 'albomycin delta 2', 'grisein', ...
# 76                                 ['Venturicidin A']
# 77                                    ['Walkmycin B']
# 78                                     ['Wychimicin']
# 79                                       ['MBX-4132']
#
#                                              Abstract  \
# 0   The present report describes our efforts to id...
# 1   Streptococcus pneumoniae is a pathogen that ma...
# 2   Gram-negative bacteria are responsible for an ...
# 3   A challenge in the treatment of Staphylococcus...
# 4   Antimicrobial peptides (AMPs) are promising al...
# ..                                                ...
# 75  Development of effective antimicrobial agents ...
# 76  Despite the remarkable advances due to the dis...
# 77  The WalK (a histidine kinase)/WalR (a response...
# 78  In the course of our screening program for new...
# 79  Bacterial ribosome rescue pathways that remove...
#
#                                              PubTator  \
# 0   [{'text': '2-pyrazol-1-yl-thiazole', 'location...
# 1   [{'text': 'choline', 'location': {'start': 906...
# 2   [{'text': 'colistin3', 'location': {'start': 4...
# 3   [{'text': 'methicillin', 'location': {'start':...
# 4   [{'text': 'lipopolysaccharide', 'location': {'...
# ..                                                ...
# 75  [{'text': 'peptidylnucleoside', 'location': {'...
# 76  [{'text': 'VentA', 'location': {'start': 1452,...
# 77  [{'text': 'walkmycin A, B and C', 'location': ...
# 78  [{'text': 'methicillin', 'location': {'start':...
# 79  [{'text': 'acylaminooxadiazoles', 'location': ...
#
#                                   PubTator_simplified
# 0   [2-pyrazol-1-yl-thiazole, 2-pyrazol-1-yl-thiaz...
# 1                                           [choline]
# 2                    [macolacin, biphenyl, colistin3]
# 3   [methicillin, CD437, retinoids, gentamicin, li...
# 4   [AMPs, Antimicrobial peptides, LPS, lipopolysa...
# ..                                                ...
# 75  [albomycins, albomycins delta1 (1a), delta2 (1...
# 76  [methicillin, VentA, aminoglycoside, gentamici...
# 77  [silica, C(44)H(44)Cl(2)O(14), BE40665A., walk...
# 78  [methicillin, beta-d-xylo-hexopyranose, Wychim...
# 79                   [MBX-4132, acylaminooxadiazoles]
#
# [80 rows x 6 columns]

# %%
pos_df.to_csv('pubtator_nature.csv', columns=["PMID","Title","Abstract","PubTator_simplified"], index=False)
