# %% [markdown]
# ## Import and Data Load

# %%
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ## PubTator

# %%
def pubtator_generate_struct(pubt_data):
    pubt_res = []
    for dic in pubt_data:
        annot_type = dic['infons']['type']
        if annot_type == "Chemical":
            annot_text = dic['text']
            annot_loc = {'start': dic['locations'][0]['offset'],
                        'end': dic['locations'][0]['offset'] + dic['locations'][0]['length']}
            res = {'text': annot_text, 'location': annot_loc}
            pubt_res.append(res)
    return pubt_res

# %%
import time

def pubtator_process(id):

    url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/export/biocjson?pmids={id}&full=true"
    res = requests.get(url)
    print(id)
    res_js = json.loads(res.content)['PubTator3']

    # Only working with abstracts
    pubt_annot = res_js[0]['passages'][1]['annotations']
    display(pubt_annot)
    pubt_res = pubtator_generate_struct(pubt_annot)

    time.sleep(0.6)

    return pubt_res

# %%
pubtator_process(11036042)
# Out:
# 11036042
# [{'id': '12',
#   'infons': {'identifier': 'MESH:D012293',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012293'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012293',
#    'biotype': 'chemical',
#    'name': 'Rifampin',
#    'accession': '@CHEMICAL_Rifampin'},
#   'text': 'rifampin',
#   'locations': [{'offset': 117, 'length': 8}]},
#  {'id': '13',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 147, 'length': 21}]},
#  {'id': '14',
#   'infons': {'identifier': 'MESH:C100307',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C100307'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C100307',
#    'biotype': 'chemical',
#    'name': 'streptolydigin',
#    'accession': '@CHEMICAL_streptolydigin'},
#   'text': 'streptolydigin',
#   'locations': [{'offset': 408, 'length': 14}]},
#  {'id': '15',
#   'infons': {'identifier': 'MESH:C051799',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C051799'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C051799',
#    'biotype': 'chemical',
#    'name': 'sorangicin A',
#    'accession': '@CHEMICAL_sorangicin_A'},
#   'text': 'sorangicin A.',
#   'locations': [{'offset': 427, 'length': 13}]},
#  {'id': '16',
#   'infons': {'identifier': 'MESH:C006361',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C006361'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C006361',
#    'biotype': 'chemical',
#    'name': 'acetopyrrothine',
#    'accession': '@CHEMICAL_acetopyrrothine'},
#   'text': 'thiolutin',
#   'locations': [{'offset': 454, 'length': 9}]},
#  {'id': '17',
#   'infons': {'identifier': 'MESH:C015265',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C015265'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C015265',
#    'biotype': 'chemical',
#    'name': 'holomycin',
#    'accession': '@CHEMICAL_holomycin'},
#   'text': 'holomycin',
#   'locations': [{'offset': 465, 'length': 9}]},
#  {'id': '18',
#   'infons': {'identifier': 'MESH:C532894',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C532894'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C532894',
#    'biotype': 'chemical',
#    'name': 'corallopyronin A',
#    'accession': '@CHEMICAL_corallopyronin_A'},
#   'text': 'corallopyronin A',
#   'locations': [{'offset': 476, 'length': 16}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:C096600',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C096600'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C096600',
#    'biotype': 'chemical',
#    'name': 'ripostatin A',
#    'accession': '@CHEMICAL_ripostatin_A'},
#   'text': 'ripostatin A',
#   'locations': [{'offset': 498, 'length': 12}]}]
# [{'text': 'rifampin', 'location': {'start': 117, 'end': 125}},
#  {'text': 'streptolydigin', 'location': {'start': 408, 'end': 422}},
#  {'text': 'sorangicin A.', 'location': {'start': 427, 'end': 440}},
#  {'text': 'thiolutin', 'location': {'start': 454, 'end': 463}},
#  {'text': 'holomycin', 'location': {'start': 465, 'end': 474}},
#  {'text': 'corallopyronin A', 'location': {'start': 476, 'end': 492}},
#  {'text': 'ripostatin A', 'location': {'start': 498, 'end': 510}}]

# %% [markdown]
# ## Procesar Dataset Positivo

# %%
pos_df = pd.read_excel("/content/DatasetPositivo.xlsx")
pos_df.dropna(subset=['Abstract'], inplace=True)
pos_df
# Out:
#          PMC_ID        PMID  \
# 0      101622.0  11036042.0
# 1    10187937.0  37192172.0
# 2     1162199.0   6258580.0
# 3     1251517.0  16189117.0
# 4     1482072.0  13681272.0
# ..          ...         ...
# 106     89784.0  10722483.0
# 107   8984893.0  35411221.0
# 108     90866.0  11709337.0
# 109   9225766.0  35723082.0
# 110   9598311.0  36290043.0
#
#                                                  Title  \
# 0    RNA polymerase inhibitors with activity agains...
# 1    Streptothricin F is a bactericidal antibiotic ...
# 2    Interaction of pseudomonic acid A with Escheri...
# 3    Efficacy of telavancin (TD-6424), a rapidly ba...
# 4                         Pharmacology of methicillin.
# ..                                                 ...
# 106  Pefloxacin-induced achilles tendon toxicity in...
# 107  Antibiotic heliomycin and its water-soluble 4-...
# 108  Target preference of 15 quinolones against Sta...
# 109  Re-establishing the utility of tetracycline-cl...
# 110  Identification of a Small Molecule That Inhibi...
#
#                                               Abstract             T5  \
# 0    A collection of rifampin-resistant mutants of ...  <pad> yes</s>
# 1    The streptothricin natural product mixture (al...  <pad> yes</s>
# 2    Sodium pseudomonate was shown to be a powerful...  <pad> yes</s>
# 3    The efficacy of telavancin, a bactericidal lip...  <pad> yes</s>
# 4    The pharmacology of a new antibiotic methicill...  <pad> yes</s>
# ..                                                 ...            ...
# 106  Despite a relatively low incidence of serious ...   <pad> no</s>
# 107  Bladder cancer is one of the most frequent can...  <pad> yes</s>
# 108  The antibacterial activities and target inhibi...  <pad> yes</s>
# 109  The progressive increase in antibiotic resista...  <pad> yes</s>
# 110  The need for novel antibiotics has become impe...  <pad> yes</s>
#
#             Alpaca                                             LaMini Score  \
# 0              Yes                                               Yes.     3
# 1              yes  The context does not provide information on wh...   2.5
# 2             Yes.  The context describes the active inhibition an...     3
# 3              Yes                                               Yes.     3
# 4    antimicrobial                                               Yes.   2.5
# ..             ...                                                ...   ...
# 106            Yes                                                No.     1
# 107        Yes; no                                               Yes.   2.5
# 108            Yes                                                No.     2
# 109            Yes                                               Yes.     3
# 110            Yes                                                No.     2
#
#     Answer  Unnamed: 9
# 0      YES         NaN
# 1      YES         NaN
# 2      YES         NaN
# 3      YES         NaN
# 4      YES         NaN
# ..     ...         ...
# 106     NO         NaN
# 107    YES         NaN
# 108    YES         NaN
# 109    YES         NaN
# 110    YES         NaN
#
# [111 rows x 10 columns]

# %%
pos_df['PMID'] = pos_df['PMID'].astype(int)
pos_df
# Out:
#          PMC_ID      PMID                                              Title  \
# 0      101622.0  11036042  RNA polymerase inhibitors with activity agains...
# 1    10187937.0  37192172  Streptothricin F is a bactericidal antibiotic ...
# 2     1162199.0   6258580  Interaction of pseudomonic acid A with Escheri...
# 3     1251517.0  16189117  Efficacy of telavancin (TD-6424), a rapidly ba...
# 4     1482072.0  13681272                       Pharmacology of methicillin.
# ..          ...       ...                                                ...
# 106     89784.0  10722483  Pefloxacin-induced achilles tendon toxicity in...
# 107   8984893.0  35411221  Antibiotic heliomycin and its water-soluble 4-...
# 108     90866.0  11709337  Target preference of 15 quinolones against Sta...
# 109   9225766.0  35723082  Re-establishing the utility of tetracycline-cl...
# 110   9598311.0  36290043  Identification of a Small Molecule That Inhibi...
#
#                                               Abstract             T5  \
# 0    A collection of rifampin-resistant mutants of ...  <pad> yes</s>
# 1    The streptothricin natural product mixture (al...  <pad> yes</s>
# 2    Sodium pseudomonate was shown to be a powerful...  <pad> yes</s>
# 3    The efficacy of telavancin, a bactericidal lip...  <pad> yes</s>
# 4    The pharmacology of a new antibiotic methicill...  <pad> yes</s>
# ..                                                 ...            ...
# 106  Despite a relatively low incidence of serious ...   <pad> no</s>
# 107  Bladder cancer is one of the most frequent can...  <pad> yes</s>
# 108  The antibacterial activities and target inhibi...  <pad> yes</s>
# 109  The progressive increase in antibiotic resista...  <pad> yes</s>
# 110  The need for novel antibiotics has become impe...  <pad> yes</s>
#
#             Alpaca                                             LaMini Score  \
# 0              Yes                                               Yes.     3
# 1              yes  The context does not provide information on wh...   2.5
# 2             Yes.  The context describes the active inhibition an...     3
# 3              Yes                                               Yes.     3
# 4    antimicrobial                                               Yes.   2.5
# ..             ...                                                ...   ...
# 106            Yes                                                No.     1
# 107        Yes; no                                               Yes.   2.5
# 108            Yes                                                No.     2
# 109            Yes                                               Yes.     3
# 110            Yes                                                No.     2
#
#     Answer  Unnamed: 9
# 0      YES         NaN
# 1      YES         NaN
# 2      YES         NaN
# 3      YES         NaN
# 4      YES         NaN
# ..     ...         ...
# 106     NO         NaN
# 107    YES         NaN
# 108    YES         NaN
# 109    YES         NaN
# 110    YES         NaN
#
# [111 rows x 10 columns]

# %%
pos_df['PubTator'] = pos_df['PMID'].apply(pubtator_process)
# Out:
# 11036042
# [{'id': '12',
#   'infons': {'identifier': 'MESH:D012293',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012293'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012293',
#    'biotype': 'chemical',
#    'name': 'Rifampin',
#    'accession': '@CHEMICAL_Rifampin'},
#   'text': 'rifampin',
#   'locations': [{'offset': 117, 'length': 8}]},
#  {'id': '13',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 147, 'length': 21}]},
#  {'id': '14',
#   'infons': {'identifier': 'MESH:C100307',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C100307'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C100307',
#    'biotype': 'chemical',
#    'name': 'streptolydigin',
#    'accession': '@CHEMICAL_streptolydigin'},
#   'text': 'streptolydigin',
#   'locations': [{'offset': 408, 'length': 14}]},
#  {'id': '15',
#   'infons': {'identifier': 'MESH:C051799',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C051799'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C051799',
#    'biotype': 'chemical',
#    'name': 'sorangicin A',
#    'accession': '@CHEMICAL_sorangicin_A'},
#   'text': 'sorangicin A.',
#   'locations': [{'offset': 427, 'length': 13}]},
#  {'id': '16',
#   'infons': {'identifier': 'MESH:C006361',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C006361'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C006361',
#    'biotype': 'chemical',
#    'name': 'acetopyrrothine',
#    'accession': '@CHEMICAL_acetopyrrothine'},
#   'text': 'thiolutin',
#   'locations': [{'offset': 454, 'length': 9}]},
#  {'id': '17',
#   'infons': {'identifier': 'MESH:C015265',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C015265'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C015265',
#    'biotype': 'chemical',
#    'name': 'holomycin',
#    'accession': '@CHEMICAL_holomycin'},
#   'text': 'holomycin',
#   'locations': [{'offset': 465, 'length': 9}]},
#  {'id': '18',
#   'infons': {'identifier': 'MESH:C532894',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C532894'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C532894',
#    'biotype': 'chemical',
#    'name': 'corallopyronin A',
#    'accession': '@CHEMICAL_corallopyronin_A'},
#   'text': 'corallopyronin A',
#   'locations': [{'offset': 476, 'length': 16}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:C096600',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C096600'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C096600',
#    'biotype': 'chemical',
#    'name': 'ripostatin A',
#    'accession': '@CHEMICAL_ripostatin_A'},
#   'text': 'ripostatin A',
#   'locations': [{'offset': 498, 'length': 12}]}]
# 37192172
# [{'id': '12630',
#   'infons': {'identifier': '470',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [470],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 470,
#    'biotype': 'species',
#    'name': '470',
#    'accession': None},
#   'text': 'Acinetobacter baumannii',
#   'locations': [{'offset': 615, 'length': 23}]},
#  {'id': '12632',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1008, 'length': 3}]},
#  {'id': '12633',
#   'infons': {'identifier': 'tmVar:p|Allele|S|16;VariantGroup:2',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': '16S',
#   'locations': [{'offset': 1396, 'length': 3}]},
#  {'id': '12634',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'steptolidine',
#   'locations': [{'offset': 1346, 'length': 12}]},
#  {'id': '12635',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 457, 'length': 3}]},
#  {'id': '12636',
#   'infons': {'identifier': '470',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [470],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 470,
#    'biotype': 'species',
#    'name': '470',
#    'accession': None},
#   'text': 'A. baumannii',
#   'locations': [{'offset': 1274, 'length': 12}]},
#  {'id': '12637',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 739, 'length': 3}]},
#  {'id': '12638',
#   'infons': {'identifier': 'tmVar:c|Allele|C|1054;VariantGroup:0',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'DNAMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'C1054',
#   'locations': [{'offset': 1405, 'length': 5}]},
#  {'id': '12639',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1507, 'length': 3}]},
#  {'id': '12640',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'toxicity',
#   'locations': [{'offset': 1219, 'length': 8}]},
#  {'id': '12641',
#   'infons': {'identifier': 'MESH:D007674',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D007674'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007674',
#    'biotype': 'disease',
#    'name': 'Kidney Diseases',
#    'accession': '@DISEASE_Kidney_Diseases'},
#   'text': 'renal toxicity',
#   'locations': [{'offset': 956, 'length': 14}]},
#  {'id': '12642',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'S-D.',
#   'locations': [{'offset': 1026, 'length': 4}]},
#  {'id': '12645',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Klebsiella pneumoniae Nevada',
#   'locations': [{'offset': 1164, 'length': 28}]},
#  {'id': '12646',
#   'infons': {'identifier': '91347',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [91347],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 91347,
#    'biotype': 'species',
#    'name': '91347',
#    'accession': None},
#   'text': 'Enterobacterales',
#   'locations': [{'offset': 588, 'length': 16}]},
#  {'id': '12647',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'nucleobase',
#   'locations': [{'offset': 1411, 'length': 10}]},
#  {'id': '12648',
#   'infons': {'identifier': 'MESH:C009156',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C009156'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C009156',
#    'biotype': 'chemical',
#    'name': 'streptothricin F',
#    'accession': '@CHEMICAL_streptothricin_F'},
#   'text': 'streptothricin F',
#   'locations': [{'offset': 439, 'length': 16}]},
#  {'id': '12650',
#   'infons': {'identifier': 'MESH:D006147',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D006147'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006147',
#    'biotype': 'chemical',
#    'name': 'Guanine',
#    'accession': '@CHEMICAL_Guanine'},
#   'text': 'guanine',
#   'locations': [{'offset': 1372, 'length': 7}]},
#  {'id': '12651',
#   'infons': {'identifier': 'MESH:D006859',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D006859'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D006859',
#    'biotype': 'chemical',
#    'name': 'Hydrogen',
#    'accession': '@CHEMICAL_Hydrogen'},
#   'text': 'hydrogen',
#   'locations': [{'offset': 1318, 'length': 8}]},
#  {'id': '12652',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'gulosamine',
#   'locations': [{'offset': 1486, 'length': 10}]},
#  {'id': '12654',
#   'infons': {'identifier': 'MESH:D013309',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013309'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013309',
#    'biotype': 'chemical',
#    'name': 'Streptothricins',
#    'accession': '@CHEMICAL_Streptothricins'},
#   'text': 'nourseothricin',
#   'locations': [{'offset': 223, 'length': 14}]},
#  {'id': '12655',
#   'infons': {'identifier': 'MESH:D013309',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013309'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013309',
#    'biotype': 'chemical',
#    'name': 'Streptothricins',
#    'accession': '@CHEMICAL_Streptothricins'},
#   'text': 'streptothricin',
#   'locations': [{'offset': 169, 'length': 14}]},
#  {'id': '12656',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'CRE',
#   'locations': [{'offset': 606, 'length': 3}]},
#  {'id': '12657',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'S-D',
#   'locations': [{'offset': 681, 'length': 3}]},
#  {'id': '12658',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'S-D',
#   'locations': [{'offset': 494, 'length': 3}]},
#  {'id': '12659',
#   'infons': {'identifier': 'MESH:D013309',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013309'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013309',
#    'biotype': 'chemical',
#    'name': 'Streptothricins',
#    'accession': '@CHEMICAL_Streptothricins'},
#   'text': 'nourseothricin',
#   'locations': [{'offset': 399, 'length': 14}]},
#  {'id': '12661',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1257, 'length': 3}]},
#  {'id': '12662',
#   'infons': {'identifier': 'MESH:D013309',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013309'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013309',
#    'biotype': 'chemical',
#    'name': 'Streptothricins',
#    'accession': '@CHEMICAL_Streptothricins'},
#   'text': 'nourseothricin',
#   'locations': [{'offset': 747, 'length': 14}]},
#  {'id': '12664',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1688, 'length': 3}]},
#  {'id': '12665',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1342, 'length': 3}]},
#  {'id': '12666',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'S-D',
#   'locations': [{'offset': 807, 'length': 3}]},
#  {'id': '12667',
#   'infons': {'identifier': 'tmVar:c|Allele|A|1196;VariantGroup:4',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'DNAMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'A1196',
#   'locations': [{'offset': 1516, 'length': 5}]},
#  {'id': '12668',
#   'infons': {'identifier': 'MESH:D008239',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008239'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008239',
#    'biotype': 'chemical',
#    'name': 'Lysine',
#    'accession': '@CHEMICAL_Lysine'},
#   'text': 'lysine',
#   'locations': [{'offset': 464, 'length': 6}]},
#  {'id': '12669',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'streptothricin D',
#   'locations': [{'offset': 476, 'length': 16}]},
#  {'id': '12670',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 799, 'length': 3}]},
#  {'id': '12671',
#   'infons': {'identifier': '562',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [562],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 562,
#    'biotype': 'species',
#    'name': '562',
#    'accession': None},
#   'text': 'Escherichia coli',
#   'locations': [{'offset': 1423, 'length': 16}]},
#  {'id': '12672',
#   'infons': {'identifier': 'MESH:D013309',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013309'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013309',
#    'biotype': 'chemical',
#    'name': 'Streptothricins',
#    'accession': '@CHEMICAL_Streptothricins'},
#   'text': 'streptothricin',
#   'locations': [{'offset': 1838, 'length': 14}]},
#  {'id': '12673',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 1063, 'length': 3}]},
#  {'id': '12674',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'murine',
#   'locations': [{'offset': 1074, 'length': 6}]},
#  {'id': '12676',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'CRE',
#   'locations': [{'offset': 644, 'length': 3}]},
#  {'id': '12678',
#   'infons': {'identifier': 'tmVar:p|SUB|S||F;VariantGroup:9',
#    'type': 'Variant',
#    'valid': False,
#    'subtype': 'ProteinMutation',
#    'database': 'litvar',
#    'rsids': [],
#    'normalized': [],
#    'normalized_id': None,
#    'biotype': 'variant'},
#   'text': 'S-F',
#   'locations': [{'offset': 673, 'length': 3}]},
#  {'id': '12679',
#   'infons': {'identifier': 'MESH:D015780',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015780'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015780',
#    'biotype': 'chemical',
#    'name': 'Carbapenems',
#    'accession': '@CHEMICAL_Carbapenems'},
#   'text': 'carbapenem',
#   'locations': [{'offset': 567, 'length': 10}]},
#  {'id': '12680',
#   'infons': {'identifier': '562',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [562],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 562,
#    'biotype': 'species',
#    'name': '562',
#    'accession': None},
#   'text': 'E. coli',
#   'locations': [{'offset': 1645, 'length': 7}]}]
# 6258580
# [{'id': '26',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Sodium pseudomonate',
#   'locations': [{'offset': 85, 'length': 19}]},
#  {'id': '27',
#   'infons': {'identifier': '37762',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [37762],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 37762,
#    'biotype': 'species',
#    'name': '37762',
#    'accession': None},
#   'text': 'Escherichia coli B',
#   'locations': [{'offset': 157, 'length': 18}]},
#  {'id': '28',
#   'infons': {'identifier': 'MESH:D007532',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D007532'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007532',
#    'biotype': 'chemical',
#    'name': 'Isoleucine',
#    'accession': '@CHEMICAL_Isoleucine'},
#   'text': 'isoleucine',
#   'locations': [{'offset': 310, 'length': 10}]},
#  {'id': '29',
#   'infons': {'identifier': 'MESH:D007532',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D007532'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007532',
#    'biotype': 'chemical',
#    'name': 'Isoleucine',
#    'accession': '@CHEMICAL_Isoleucine'},
#   'text': 'Ile',
#   'locations': [{'offset': 352, 'length': 3}]},
#  {'id': '30',
#   'infons': {'identifier': 'MESH:D000249',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000249'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000249',
#    'biotype': 'chemical',
#    'name': 'Adenosine Monophosphate',
#    'accession': '@CHEMICAL_Adenosine_Monophosphate'},
#   'text': 'AMP',
#   'locations': [{'offset': 370, 'length': 3}]},
#  {'id': '31',
#   'infons': {'identifier': 'MESH:C107241',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C107241'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C107241',
#    'biotype': 'chemical',
#    'name': 'diphosphoric acid',
#    'accession': '@CHEMICAL_diphosphoric_acid'},
#   'text': 'pyrophosphate',
#   'locations': [{'offset': 401, 'length': 13}]},
#  {'id': '32',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': '[14C]isoleucine',
#   'locations': [{'offset': 471, 'length': 15}]},
#  {'id': '33',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': '14C]Ile',
#   'locations': [{'offset': 506, 'length': 7}]},
#  {'id': '34',
#   'infons': {'identifier': 'MESH:D000249',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000249'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000249',
#    'biotype': 'chemical',
#    'name': 'Adenosine Monophosphate',
#    'accession': '@CHEMICAL_Adenosine_Monophosphate'},
#   'text': 'AMP',
#   'locations': [{'offset': 528, 'length': 3}]},
#  {'id': '35',
#   'infons': {'identifier': 'MESH:C107241',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C107241'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C107241',
#    'biotype': 'chemical',
#    'name': 'diphosphoric acid',
#    'accession': '@CHEMICAL_diphosphoric_acid'},
#   'text': 'pyrophosphate',
#   'locations': [{'offset': 584, 'length': 13}]},
#  {'id': '36',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': "Sodium [9'-3H]pseudomonate",
#   'locations': [{'offset': 748, 'length': 26}]},
#  {'id': '37',
#   'infons': {'identifier': 'MESH:D014508',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014508'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014508',
#    'biotype': 'chemical',
#    'name': 'Urea',
#    'accession': '@CHEMICAL_Urea'},
#   'text': 'urea',
#   'locations': [{'offset': 945, 'length': 4}]},
#  {'id': '38',
#   'infons': {'identifier': 'MESH:D012967',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D012967'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D012967',
#    'biotype': 'chemical',
#    'name': 'Sodium Dodecyl Sulfate',
#    'accession': '@CHEMICAL_Sodium_Dodecyl_Sulfate'},
#   'text': 'sodium dodecyl sulphate',
#   'locations': [{'offset': 979, 'length': 23}]},
#  {'id': '39',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': "sodium [9'-3H]pseudomonate",
#   'locations': [{'offset': 1031, 'length': 26}]},
#  {'id': '40',
#   'infons': {'identifier': '4932',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [4932],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 4932,
#    'biotype': 'species',
#    'name': '4932',
#    'accession': None},
#   'text': 'yeast',
#   'locations': [{'offset': 1147, 'length': 5}]},
#  {'id': '41',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'rat liver',
#   'locations': [{'offset': 1164, 'length': 9}]},
#  {'id': '42',
#   'infons': {'identifier': 'MESH:D007532',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D007532'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D007532',
#    'biotype': 'chemical',
#    'name': 'Isoleucine',
#    'accession': '@CHEMICAL_Isoleucine'},
#   'text': 'isoleucine',
#   'locations': [{'offset': 1243, 'length': 10}]},
#  {'id': '43',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'rat liver',
#   'locations': [{'offset': 1311, 'length': 9}]},
#  {'id': '44',
#   'infons': {'identifier': '37762',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [37762],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 37762,
#    'biotype': 'species',
#    'name': '37762',
#    'accession': None},
#   'text': 'E. coli B',
#   'locations': [{'offset': 1325, 'length': 9}]},
#  {'id': '45',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'rat liver',
#   'locations': [{'offset': 1386, 'length': 9}]},
#  {'id': '46',
#   'infons': {'identifier': '37762',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [37762],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 37762,
#    'biotype': 'species',
#    'name': '37762',
#    'accession': None},
#   'text': 'E. coli B',
#   'locations': [{'offset': 1433, 'length': 9}]},
#  {'id': '47',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'toxicity',
#   'locations': [{'offset': 1484, 'length': 8}]}]
# 16189117
# [{'id': '29',
#   'infons': {'identifier': 'MESH:C487637',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C487637'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C487637',
#    'biotype': 'chemical',
#    'name': 'telavancin',
#    'accession': '@CHEMICAL_telavancin'},
#   'text': 'telavancin',
#   'locations': [{'offset': 213, 'length': 10}]},
#  {'id': '30',
#   'infons': {'identifier': 'MESH:D000077427',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000077427'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000077427',
#    'biotype': 'chemical',
#    'name': 'Lipoglycopeptides',
#    'accession': '@CHEMICAL_Lipoglycopeptides'},
#   'text': 'lipoglycopeptide',
#   'locations': [{'offset': 240, 'length': 16}]},
#  {'id': '31',
#   'infons': {'identifier': 'MESH:D014640',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014640'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014640',
#    'biotype': 'chemical',
#    'name': 'Vancomycin',
#    'accession': '@CHEMICAL_Vancomycin'},
#   'text': 'vancomycin',
#   'locations': [{'offset': 282, 'length': 10}]},
#  {'id': '32',
#   'infons': {'identifier': 'MESH:D000069349',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000069349'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000069349',
#    'biotype': 'chemical',
#    'name': 'Linezolid',
#    'accession': '@CHEMICAL_Linezolid'},
#   'text': 'linezolid',
#   'locations': [{'offset': 297, 'length': 9}]},
#  {'id': '33',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 315, 'length': 11}]},
#  {'id': '34',
#   'infons': {'identifier': '1280',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1280],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1280,
#    'biotype': 'species',
#    'name': '1280',
#    'accession': None},
#   'text': 'Staphylococcus aureus',
#   'locations': [{'offset': 337, 'length': 21}]},
#  {'id': '35',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'MRSA',
#   'locations': [{'offset': 360, 'length': 4}]},
#  {'id': '36',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'murine',
#   'locations': [{'offset': 371, 'length': 6}]},
#  {'id': '37',
#   'infons': {'identifier': 'MESH:D011014',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D011014'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D011014',
#    'biotype': 'disease',
#    'name': 'Pneumonia',
#    'accession': '@DISEASE_Pneumonia'},
#   'text': 'pneumonia',
#   'locations': [{'offset': 378, 'length': 9}]},
#  {'id': '38',
#   'infons': {'identifier': 'MESH:C487637',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C487637'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C487637',
#    'biotype': 'chemical',
#    'name': 'telavancin',
#    'accession': '@CHEMICAL_telavancin'},
#   'text': 'Telavancin',
#   'locations': [{'offset': 395, 'length': 10}]},
#  {'id': '39',
#   'infons': {'identifier': 'MESH:D014640',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014640'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014640',
#    'biotype': 'chemical',
#    'name': 'Vancomycin',
#    'accession': '@CHEMICAL_Vancomycin'},
#   'text': 'vancomycin',
#   'locations': [{'offset': 481, 'length': 10}]},
#  {'id': '40',
#   'infons': {'identifier': 'MESH:D000069349',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000069349'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000069349',
#    'biotype': 'chemical',
#    'name': 'Linezolid',
#    'accession': '@CHEMICAL_Linezolid'},
#   'text': 'linezolid',
#   'locations': [{'offset': 496, 'length': 9}]},
#  {'id': '41',
#   'infons': {'identifier': '9606',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [9606],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 9606,
#    'biotype': 'species',
#    'name': '9606',
#    'accession': None},
#   'text': 'human',
#   'locations': [{'offset': 509, 'length': 5}]},
#  {'id': '42',
#   'infons': {'identifier': 'MESH:C487637',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C487637'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C487637',
#    'biotype': 'chemical',
#    'name': 'telavancin',
#    'accession': '@CHEMICAL_telavancin'},
#   'text': 'telavancin',
#   'locations': [{'offset': 646, 'length': 10}]},
#  {'id': '43',
#   'infons': {'identifier': 'MESH:D011023',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D011023'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D011023',
#    'biotype': 'disease',
#    'name': 'Pneumonia Staphylococcal',
#    'accession': '@DISEASE_Pneumonia_Staphylococcal'},
#   'text': 'MRSA pneumonia',
#   'locations': [{'offset': 674, 'length': 14}]}]
# 13681272
# [{'id': '8',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': 'methicillin',
#   'locations': [{'offset': 66, 'length': 11}]},
#  {'id': '9',
#   'infons': {'identifier': 'MESH:D008712',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008712'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008712',
#    'biotype': 'chemical',
#    'name': 'Methicillin',
#    'accession': '@CHEMICAL_Methicillin'},
#   'text': '6(2:6-dimethoxybenzamido)-penicillanic acid',
#   'locations': [{'offset': 79, 'length': 43}]},
#  {'id': '10',
#   'infons': {'identifier': 'MESH:D010400',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D010400'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D010400',
#    'biotype': 'chemical',
#    'name': 'Penicillin G',
#    'accession': '@CHEMICAL_Penicillin_G'},
#   'text': 'penicillin G',
#   'locations': [{'offset': 178, 'length': 12}]},
#  {'id': '11',
#   'infons': {'identifier': 'MESH:D010146',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D010146'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D010146',
#    'biotype': 'disease',
#    'name': 'Pain',
#    'accession': '@DISEASE_Pain'},
#   'text': 'pain',
#   'locations': [{'offset': 281, 'length': 4}]},
#  {'id': '12',
#   'infons': {'identifier': 'MESH:D010400',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D010400'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D010400',
#    'biotype': 'chemical',
#    'name': 'Penicillin G',
#    'accession': '@CHEMICAL_Penicillin_G'},
#   'text': 'penicillin G.',
#   'locations': [{'offset': 483, 'length': 13}]},
#  {'id': '13',
#   'infons': {'identifier': 'MESH:D010400',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D010400'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D010400',
#    'biotype': 'chemical',
#    'name': 'Penicillin G',
#    'accession': '@CHEMICAL_Penicillin_G'},
#   'text': 'penicillin G.',
#   'locations': [{'offset': 737, 'length': 13}]}]
# 5847736
# [{'id': '7',
#   'infons': {'identifier': 'MESH:D002512',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002512'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002512',
#    'biotype': 'chemical',
#    'name': 'Cephalothin',
#    'accession': '@CHEMICAL_Cephalothin'},
#   'text': 'cephalothin',
#   'locations': [{'offset': 209, 'length': 11}]},
#  {'id': '8',
#   'infons': {'identifier': 'MESH:D002512',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002512'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002512',
#    'biotype': 'chemical',
#    'name': 'Cephalothin',
#    'accession': '@CHEMICAL_Cephalothin'},
#   'text': 'cephalothin',
#   'locations': [{'offset': 562, 'length': 11}]},
#  {'id': '9',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Pseudomonas spp',
#   'locations': [{'offset': 711, 'length': 15}]},
#  {'id': '10',
#   'infons': {'identifier': 'MESH:D002512',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002512'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002512',
#    'biotype': 'chemical',
#    'name': 'Cephalothin',
#    'accession': '@CHEMICAL_Cephalothin'},
#   'text': 'cephalothin',
#   'locations': [{'offset': 815, 'length': 11}]},
#  {'id': '11',
#   'infons': {'identifier': 'MESH:D002512',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002512'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002512',
#    'biotype': 'chemical',
#    'name': 'Cephalothin',
#    'accession': '@CHEMICAL_Cephalothin'},
#   'text': 'cephalothin',
#   'locations': [{'offset': 860, 'length': 11}]}]
# 4901344
# [{'id': '14',
#   'infons': {'identifier': '9606',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [9606],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 9606,
#    'biotype': 'species',
#    'name': '9606',
#    'accession': None},
#   'text': 'patients',
#   'locations': [{'offset': 143, 'length': 8}]},
#  {'id': '15',
#   'infons': {'identifier': 'MESH:D029481',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D029481'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D029481',
#    'biotype': 'disease',
#    'name': 'Bronchitis Chronic',
#    'accession': '@DISEASE_Bronchitis_Chronic'},
#   'text': 'chronic bronchitis',
#   'locations': [{'offset': 174, 'length': 18}]},
#  {'id': '16',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'trimethoprim',
#   'locations': [{'offset': 235, 'length': 12}]},
#  {'id': '17',
#   'infons': {'identifier': 'MESH:D013420',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013420',
#    'biotype': 'chemical',
#    'name': 'Sulfamethoxazole',
#    'accession': '@CHEMICAL_Sulfamethoxazole'},
#   'text': 'sulphamethoxazole',
#   'locations': [{'offset': 260, 'length': 17}]},
#  {'id': '18',
#   'infons': {'identifier': 'MESH:D000667',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000667'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000667',
#    'biotype': 'chemical',
#    'name': 'Ampicillin',
#    'accession': '@CHEMICAL_Ampicillin'},
#   'text': 'ampicillin',
#   'locations': [{'offset': 297, 'length': 10}]},
#  {'id': '19',
#   'infons': {'identifier': 'MESH:D003234',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D003234'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D003234',
#    'biotype': 'disease',
#    'name': 'Conjunctivitis Bacterial',
#    'accession': '@DISEASE_Conjunctivitis_Bacterial'},
#   'text': 'purulence',
#   'locations': [{'offset': 485, 'length': 9}]},
#  {'id': '20',
#   'infons': {'identifier': 'MESH:D015662',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015662'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015662',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim Sulfamethoxazole Drug Combination',
#    'accession': '@CHEMICAL_Trimethoprim_Sulfamethoxazole_Drug_Combination'},
#   'text': 'trimethoprim-sulphamethoxazole',
#   'locations': [{'offset': 635, 'length': 30}]},
#  {'id': '21',
#   'infons': {'identifier': 'MESH:D029481',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D029481'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D029481',
#    'biotype': 'disease',
#    'name': 'Bronchitis Chronic',
#    'accession': '@DISEASE_Bronchitis_Chronic'},
#   'text': 'chronic bronchitis',
#   'locations': [{'offset': 728, 'length': 18}]}]
# 8726004
# [{'id': '39',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'Epiroprim',
#   'locations': [{'offset': 119, 'length': 9}]},
#  {'id': '40',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 130, 'length': 3}]},
#  {'id': '41',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'Ro 11-8958',
#   'locations': [{'offset': 135, 'length': 10}]},
#  {'id': '42',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 214, 'length': 3}]},
#  {'id': '43',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'staphylococci',
#   'locations': [{'offset': 255, 'length': 13}]},
#  {'id': '44',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'trimethoprim',
#   'locations': [{'offset': 356, 'length': 12}]},
#  {'id': '45',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 370, 'length': 3}]},
#  {'id': '46',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 376, 'length': 3}]},
#  {'id': '47',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 404, 'length': 3}]},
#  {'id': '48',
#   'infons': {'identifier': 'MESH:D003622',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D003622'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D003622',
#    'biotype': 'chemical',
#    'name': 'Dapsone',
#    'accession': '@CHEMICAL_Dapsone'},
#   'text': 'dapsone',
#   'locations': [{'offset': 494, 'length': 7}]},
#  {'id': '49',
#   'infons': {'identifier': 'MESH:C007792',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C007792'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C007792',
#    'biotype': 'chemical',
#    'name': 'Fumigant 93',
#    'accession': '@CHEMICAL_Fumigant_93'},
#   'text': 'DDS',
#   'locations': [{'offset': 503, 'length': 3}]},
#  {'id': '50',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 580, 'length': 3}]},
#  {'id': '51',
#   'infons': {'identifier': 'MESH:D013420',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013420',
#    'biotype': 'chemical',
#    'name': 'Sulfamethoxazole',
#    'accession': '@CHEMICAL_Sulfamethoxazole'},
#   'text': 'sulfamethoxazole',
#   'locations': [{'offset': 601, 'length': 16}]},
#  {'id': '52',
#   'infons': {'identifier': 'MESH:D013420',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D013420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013420',
#    'biotype': 'chemical',
#    'name': 'Sulfamethoxazole',
#    'accession': '@CHEMICAL_Sulfamethoxazole'},
#   'text': 'SMZ',
#   'locations': [{'offset': 619, 'length': 3}]},
#  {'id': '53',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'EPM-DDS',
#   'locations': [{'offset': 629, 'length': 7}]},
#  {'id': '54',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 790, 'length': 3}]},
#  {'id': '55',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'staphylococci',
#   'locations': [{'offset': 804, 'length': 13}]},
#  {'id': '56',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 854, 'length': 3}]},
#  {'id': '57',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 884, 'length': 3}]},
#  {'id': '58',
#   'infons': {'identifier': '480',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [480],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 480,
#    'biotype': 'species',
#    'name': '480',
#    'accession': None},
#   'text': 'Moraxella catarrhalis',
#   'locations': [{'offset': 896, 'length': 21}]},
#  {'id': '59',
#   'infons': {'identifier': '487',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [487],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 487,
#    'biotype': 'species',
#    'name': '487',
#    'accession': None},
#   'text': 'Neisseria meningitidis',
#   'locations': [{'offset': 919, 'length': 22}]},
#  {'id': '60',
#   'infons': {'identifier': '29523',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [29523],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 29523,
#    'biotype': 'species',
#    'name': '29523',
#    'accession': None},
#   'text': 'Bacteroides spp',
#   'locations': [{'offset': 947, 'length': 15}]},
#  {'id': '61',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 993, 'length': 3}]},
#  {'id': '62',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 1095, 'length': 3}]},
#  {'id': '63',
#   'infons': {'identifier': 'MESH:C007792',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C007792'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C007792',
#    'biotype': 'chemical',
#    'name': 'Fumigant 93',
#    'accession': '@CHEMICAL_Fumigant_93'},
#   'text': 'DDS',
#   'locations': [{'offset': 1125, 'length': 3}]},
#  {'id': '64',
#   'infons': {'identifier': 'MESH:C082896',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C082896'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C082896',
#    'biotype': 'chemical',
#    'name': 'epiroprim',
#    'accession': '@CHEMICAL_epiroprim'},
#   'text': 'EPM',
#   'locations': [{'offset': 1271, 'length': 3}]},
#  {'id': '65',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'EPM-DDS',
#   'locations': [{'offset': 1283, 'length': 7}]},
#  {'id': '66',
#   'infons': {'identifier': 'MESH:D013203',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D013203'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D013203',
#    'biotype': 'disease',
#    'name': 'Staphylococcal Infections',
#    'accession': '@DISEASE_Staphylococcal_Infections'},
#   'text': 'staphylococcal infections',
#   'locations': [{'offset': 1348, 'length': 25}]},
#  {'id': '67',
#   'infons': {'identifier': '10090',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [10090],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 10090,
#    'biotype': 'species',
#    'name': '10090',
#    'accession': None},
#   'text': 'mouse',
#   'locations': [{'offset': 1379, 'length': 5}]},
#  {'id': '68',
#   'infons': {'identifier': 'MESH:D018805',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D018805'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D018805',
#    'biotype': 'disease',
#    'name': 'Sepsis',
#    'accession': '@DISEASE_Sepsis'},
#   'text': 'septicemia',
#   'locations': [{'offset': 1385, 'length': 10}]},
#  {'id': '69',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'EPM-DDS',
#   'locations': [{'offset': 1419, 'length': 7}]},
#  {'id': '70',
#   'infons': {'identifier': '4754',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [4754],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 4754,
#    'biotype': 'species',
#    'name': '4754',
#    'accession': None},
#   'text': 'Pneumocystis carinii',
#   'locations': [{'offset': 1476, 'length': 20}]},
#  {'id': '71',
#   'infons': {'identifier': '5810',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [5810],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 5810,
#    'biotype': 'species',
#    'name': '5810',
#    'accession': None},
#   'text': 'Toxoplasma',
#   'locations': [{'offset': 1501, 'length': 10}]},
#  {'id': '72',
#   'infons': {'identifier': 'MESH:D014295',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014295'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014295',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim',
#    'accession': '@CHEMICAL_Trimethoprim'},
#   'text': 'TMP',
#   'locations': [{'offset': 1650, 'length': 3}]},
#  {'id': '73',
#   'infons': {'identifier': 'MESH:D015662',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015662'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015662',
#    'biotype': 'chemical',
#    'name': 'Trimethoprim Sulfamethoxazole Drug Combination',
#    'accession': '@CHEMICAL_Trimethoprim_Sulfamethoxazole_Drug_Combination'},
#   'text': 'TMP-SMZ',
#   'locations': [{'offset': 1658, 'length': 7}]}]
# 2552910
# [{'id': '20',
#   'infons': {'identifier': 'MESH:D017576',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D017576'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D017576',
#    'biotype': 'chemical',
#    'name': 'Daptomycin',
#    'accession': '@CHEMICAL_Daptomycin'},
#   'text': 'daptomycin',
#   'locations': [{'offset': 146, 'length': 10}]},
#  {'id': '21',
#   'infons': {'identifier': 'MESH:D014640',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014640'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014640',
#    'biotype': 'chemical',
#    'name': 'Vancomycin',
#    'accession': '@CHEMICAL_Vancomycin'},
#   'text': 'vancomycin',
#   'locations': [{'offset': 258, 'length': 10}]},
#  {'id': '22',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'gram-positive bacteria',
#   'locations': [{'offset': 279, 'length': 22}]},
#  {'id': '23',
#   'infons': {'identifier': '1578',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [1578],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 1578,
#    'biotype': 'species',
#    'name': '1578',
#    'accession': None},
#   'text': 'Lactobacillus',
#   'locations': [{'offset': 326, 'length': 13}]},
#  {'id': '24',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Pediococcus spp',
#   'locations': [{'offset': 345, 'length': 15}]},
#  {'id': '25',
#   'infons': {'identifier': 'MESH:D004917',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D004917'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D004917',
#    'biotype': 'chemical',
#    'name': 'Erythromycin',
#    'accession': '@CHEMICAL_Erythromycin'},
#   'text': 'Erythromycin',
#   'locations': [{'offset': 362, 'length': 12}]},
#  {'id': '26',
#   'infons': {'identifier': 'MESH:D017576',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D017576'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D017576',
#    'biotype': 'chemical',
#    'name': 'Daptomycin',
#    'accession': '@CHEMICAL_Daptomycin'},
#   'text': 'deptomycin',
#   'locations': [{'offset': 376, 'length': 10}]},
#  {'id': '27',
#   'infons': {'identifier': 'MESH:D002981',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002981'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002981',
#    'biotype': 'chemical',
#    'name': 'Clindamycin',
# ...
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C007912',
#    'biotype': 'chemical',
#    'name': 'heliomycin',
#    'accession': '@CHEMICAL_heliomycin'},
#   'text': 'heliomycin',
#   'locations': [{'offset': 1865, 'length': 10}]},
#  {'id': '67',
#   'infons': {'identifier': 'MESH:D014867',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D014867'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D014867',
#    'biotype': 'chemical',
#    'name': 'Water',
#    'accession': '@CHEMICAL_Water'},
#   'text': 'water',
#   'locations': [{'offset': 1884, 'length': 5}]},
#  {'id': '68',
#   'infons': {'identifier': 'CVCL:0554',
#    'type': 'CellLine',
#    'valid': True,
#    'normalized': ['0554'],
#    'database': 'cvcl',
#    'normalized_id': '0554',
#    'biotype': 'cellline',
#    'name': '0554',
#    'accession': None},
#   'text': 'T24',
#   'locations': [{'offset': 2041, 'length': 3}]},
#  {'id': '69',
#   'infons': {'identifier': 'MESH:D001749',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D001749'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D001749',
#    'biotype': 'disease',
#    'name': 'Urinary Bladder Neoplasms',
#    'accession': '@DISEASE_Urinary_Bladder_Neoplasms'},
#   'text': 'bladder cancer',
#   'locations': [{'offset': 2045, 'length': 14}]}]
# 11709337
# [{'id': '32',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 180, 'length': 10}]},
#  {'id': '33',
#   'infons': {'type': 'Species',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'species'},
#   'text': 'Staphylococcus aureus MS5935',
#   'locations': [{'offset': 283, 'length': 28}]},
#  {'id': '34',
#   'infons': {'identifier': 'MESH:D009643',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D009643'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D009643',
#    'biotype': 'chemical',
#    'name': 'Norfloxacin',
#    'accession': '@CHEMICAL_Norfloxacin'},
#   'text': 'norfloxacin',
#   'locations': [{'offset': 330, 'length': 11}]},
#  {'id': '35',
#   'infons': {'identifier': 'MESH:C062127',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C062127'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C062127',
#    'biotype': 'chemical',
#    'name': 'nadifloxacin',
#    'accession': '@CHEMICAL_nadifloxacin'},
#   'text': 'nadifloxacin',
#   'locations': [{'offset': 346, 'length': 12}]},
#  {'id': '36',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 411, 'length': 10}]},
#  {'id': '37',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 677, 'length': 10}]},
#  {'id': '38',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 957, 'length': 10}]},
#  {'id': '39',
#   'infons': {'identifier': 'MESH:D015363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015363',
#    'biotype': 'chemical',
#    'name': 'Quinolones',
#    'accession': '@CHEMICAL_Quinolones'},
#   'text': 'quinolones',
#   'locations': [{'offset': 1206, 'length': 10}]},
#  {'id': '40',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'I quinolones',
#   'locations': [{'offset': 1261, 'length': 12}]},
#  {'id': '41',
#   'infons': {'identifier': 'MESH:D009643',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D009643'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D009643',
#    'biotype': 'chemical',
#    'name': 'Norfloxacin',
#    'accession': '@CHEMICAL_Norfloxacin'},
#   'text': 'norfloxacin',
#   'locations': [{'offset': 1275, 'length': 11}]},
#  {'id': '42',
#   'infons': {'identifier': 'MESH:D015365',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015365'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015365',
#    'biotype': 'chemical',
#    'name': 'Enoxacin',
#    'accession': '@CHEMICAL_Enoxacin'},
#   'text': 'enoxacin',
#   'locations': [{'offset': 1288, 'length': 8}]},
#  {'id': '43',
#   'infons': {'identifier': 'MESH:D016576',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D016576'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D016576',
#    'biotype': 'chemical',
#    'name': 'Fleroxacin',
#    'accession': '@CHEMICAL_Fleroxacin'},
#   'text': 'fleroxacin',
#   'locations': [{'offset': 1298, 'length': 10}]},
#  {'id': '44',
#   'infons': {'identifier': 'MESH:D002939',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D002939'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D002939',
#    'biotype': 'chemical',
#    'name': 'Ciprofloxacin',
#    'accession': '@CHEMICAL_Ciprofloxacin'},
#   'text': 'ciprofloxacin',
#   'locations': [{'offset': 1310, 'length': 13}]},
#  {'id': '45',
#   'infons': {'identifier': 'MESH:C053091',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C053091'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C053091',
#    'biotype': 'chemical',
#    'name': 'lomefloxacin',
#    'accession': '@CHEMICAL_lomefloxacin'},
#   'text': 'lomefloxacin',
#   'locations': [{'offset': 1325, 'length': 12}]},
#  {'id': '46',
#   'infons': {'identifier': 'MESH:C080163',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C080163'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C080163',
#    'biotype': 'chemical',
#    'name': 'trovafloxacin',
#    'accession': '@CHEMICAL_trovafloxacin'},
#   'text': 'trovafloxacin',
#   'locations': [{'offset': 1339, 'length': 13}]},
#  {'id': '47',
#   'infons': {'identifier': 'MESH:C075375',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C075375'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C075375',
#    'biotype': 'chemical',
#    'name': 'grepafloxacin',
#    'accession': '@CHEMICAL_grepafloxacin'},
#   'text': 'grepafloxacin',
#   'locations': [{'offset': 1354, 'length': 13}]},
#  {'id': '48',
#   'infons': {'identifier': 'MESH:D015242',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D015242'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D015242',
#    'biotype': 'chemical',
#    'name': 'Ofloxacin',
#    'accession': '@CHEMICAL_Ofloxacin'},
#   'text': 'ofloxacin',
#   'locations': [{'offset': 1369, 'length': 9}]},
#  {'id': '49',
#   'infons': {'identifier': 'MESH:D064704',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D064704'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064704',
#    'biotype': 'chemical',
#    'name': 'Levofloxacin',
#    'accession': '@CHEMICAL_Levofloxacin'},
#   'text': 'levofloxacin',
#   'locations': [{'offset': 1384, 'length': 12}]},
#  {'id': '50',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'II quinolones',
#   'locations': [{'offset': 1425, 'length': 13}]},
#  {'id': '51',
#   'infons': {'identifier': 'MESH:C061363',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C061363'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C061363',
#    'biotype': 'chemical',
#    'name': 'sparfloxacin',
#    'accession': '@CHEMICAL_sparfloxacin'},
#   'text': 'sparfloxacin',
#   'locations': [{'offset': 1440, 'length': 12}]},
#  {'id': '52',
#   'infons': {'identifier': 'MESH:C062127',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C062127'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C062127',
#    'biotype': 'chemical',
#    'name': 'nadifloxacin',
#    'accession': '@CHEMICAL_nadifloxacin'},
#   'text': 'nadifloxacin',
#   'locations': [{'offset': 1457, 'length': 12}]},
#  {'id': '53',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'type III quinolones',
#   'locations': [{'offset': 1497, 'length': 19}]},
#  {'id': '54',
#   'infons': {'identifier': 'MESH:D000077734',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000077734'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000077734',
#    'biotype': 'chemical',
#    'name': 'Gatifloxacin',
#    'accession': '@CHEMICAL_Gatifloxacin'},
#   'text': 'gatifloxacin',
#   'locations': [{'offset': 1518, 'length': 12}]},
#  {'id': '55',
#   'infons': {'identifier': 'MESH:C078052',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C078052'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C078052',
#    'biotype': 'chemical',
#    'name': 'pazufloxacin',
#    'accession': '@CHEMICAL_pazufloxacin'},
#   'text': 'pazufloxacin',
#   'locations': [{'offset': 1532, 'length': 12}]},
#  {'id': '56',
#   'infons': {'identifier': 'MESH:D000077266',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D000077266'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D000077266',
#    'biotype': 'chemical',
#    'name': 'Moxifloxacin',
#    'accession': '@CHEMICAL_Moxifloxacin'},
#   'text': 'moxifloxacin',
#   'locations': [{'offset': 1546, 'length': 12}]},
#  {'id': '57',
#   'infons': {'identifier': 'MESH:C057477',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['C057477'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'C057477',
#    'biotype': 'chemical',
#    'name': 'clinafloxacin',
#    'accession': '@CHEMICAL_clinafloxacin'},
#   'text': 'clinafloxacin',
#   'locations': [{'offset': 1564, 'length': 13}]},
#  {'id': '58',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'II quinolones',
#   'locations': [{'offset': 1616, 'length': 13}]},
#  {'id': '59',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'Type III quinolones',
#   'locations': [{'offset': 1692, 'length': 19}]}]
# 35723082
# []
# 36290043
# [{'id': '37931',
#   'infons': {'identifier': '562',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [562],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 562,
#    'biotype': 'species',
#    'name': '562',
#    'accession': None},
#   'text': 'Escherichia coli',
#   'locations': [{'offset': 1638, 'length': 16}]},
#  {'id': '37932',
#   'infons': {'identifier': '4932',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [4932],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 4932,
#    'biotype': 'species',
#    'name': '4932',
#    'accession': None},
#   'text': 'yeast',
#   'locations': [{'offset': 865, 'length': 5}]},
#  {'id': '37933',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'IMB-0042',
#   'locations': [{'offset': 1118, 'length': 8}]},
#  {'id': '37934',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 796, 'length': 3}]},
#  {'id': '37935',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'lipopolysaccharide',
#   'locations': [{'offset': 280, 'length': 18}]},
#  {'id': '37936',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'IMB-0042',
#   'locations': [{'offset': 1234, 'length': 8}]},
#  {'id': '37937',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 1318, 'length': 3}]},
#  {'id': '37938',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'IMB-0042',
#   'locations': [{'offset': 1340, 'length': 8}]},
#  {'id': '37939',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 300, 'length': 3}]},
#  {'id': '37940',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 1596, 'length': 3}]},
#  {'id': '37941',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 941, 'length': 3}]},
#  {'id': '37942',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 713, 'length': 3}]},
#  {'id': '37943',
#   'infons': {'identifier': '-',
#    'type': 'Chemical',
#    'valid': False,
#    'normalized_id': None,
#    'biotype': 'chemical'},
#   'text': 'IMB-0042',
#   'locations': [{'offset': 1068, 'length': 8}]},
#  {'id': '37944',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 556, 'length': 3}]},
#  {'id': '37945',
#   'infons': {'identifier': 'MESH:D008070',
#    'type': 'Chemical',
#    'valid': True,
#    'normalized': ['D008070'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D008070',
#    'biotype': 'chemical',
#    'name': 'Lipopolysaccharides',
#    'accession': '@CHEMICAL_Lipopolysaccharides'},
#   'text': 'LPS',
#   'locations': [{'offset': 352, 'length': 3}]},
#  {'id': '37946',
#   'infons': {'identifier': '562',
#    'type': 'Species',
#    'valid': True,
#    'normalized': [562],
#    'database': 'ncbi_taxonomy',
#    'normalized_id': 562,
#    'biotype': 'species',
#    'name': '562',
#    'accession': None},
#   'text': 'Escherichia coli',
#   'locations': [{'offset': 1192, 'length': 16}]},
#  {'id': '37947',
#   'infons': {'identifier': 'MESH:D064420',
#    'type': 'Disease',
#    'valid': True,
#    'normalized': ['D064420'],
#    'database': 'ncbi_mesh',
#    'normalized_id': 'D064420',
#    'biotype': 'disease',
#    'name': 'Drug-Related Side Effects and Adverse Reactions',
#    'accession': '@DISEASE_Drug_Related_Side_Effects_and_Adverse_Reactions'},
#   'text': 'cytotoxicity',
#   'locations': [{'offset': 1464, 'length': 12}]}]

# %%
pos_df[ pos_df['PubTator'].str.len() < 1 ]
# Out:
#         PMC_ID      PMID                                              Title  \
# 25   2466982.0   4914633                 Cephalexin--a new oral antibiotic.
# 33   3024282.0  21194422  An open randomized clinical trial in comparing...
# 35   3167646.0  22460279  Host defence peptides: antimicrobial and immun...
# 57   4359184.0  25644122  Pharmacokinetics of cefozopran by single and m...
# 66   4675762.0  26391612  In Vitro Activity of Oral Cephalosporins (Cefp...
# 74   5042094.0  26289137  Evidence for the use of demeclocycline in the ...
# 87   7467700.0  32917596  Globally deimmunized lysostaphin evades human ...
# 88   7566547.0  32712655  High in vitro activity of DIS-73285, a novel a...
# 96   8316002.0  33875545  Inhibition of Escherichia coli Lipoprotein Dia...
# 100  8665510.0  34895348  A fresh look at the role of spiramycin in prev...
# 103  8805024.0  35100868  An Analysis of the Novel Fluorocycline TP-6076...
# 104  8864998.0  34969066  Flomoxef for neonates: extending options for t...
# 109  9225766.0  35723082  Re-establishing the utility of tetracycline-cl...
#
#                                               Abstract             T5  \
# 25   The pharmacology, antimicrobial activity and c...  <pad> yes</s>
# 33   Several studies have demonstrated the efficacy...  <pad> yes</s>
# 35   The rapidly increasing incidence of multidrug-...  <pad> yes</s>
# 57   Cefozopran is a parenteral cephalosporin with ...  <pad> yes</s>
# 66   The global emergence of pathogens of urinary-t...  <pad> yes</s>
# 74   Hyponatraemia (HN) is the most common electrol...   <pad> no</s>
# 87   There is a critical need for novel therapies t...  <pad> yes</s>
# 88   The rising incidence of antimicrobial resistan...  <pad> yes</s>
# 96   Lipoprotein diacylglyceryl transferase (Lgt) c...  <pad> yes</s>
# 100  We aimed to investigate the effect of antepart...  <pad> yes</s>
# 103  Antibiotic resistance among bacterial pathogen...  <pad> yes</s>
# 104  Neonatal sepsis is a serious and frequently le...  <pad> yes</s>
# 109  The progressive increase in antibiotic resista...  <pad> yes</s>
#
#        Alpaca                                             LaMini Score Answer  \
# 25        Yes                                               Yes.     3    YES
# 33    No; yes  Yes. For AS + SMP FDC; the same drugs are used...   2.5    YES
# 35        Yes                                               Yes.     3    YES
# 57        Yes                                               Yes.     3    YES
# 66        Yes                                               Yes.     3    YES
# 74   Yes; yes                                                No.     1     NO
# 87        yes                                                No.     2    YES
# 88        yes                                               Yes.     3    YES
# 96        Yes                                               Yes.     3    YES
# 100      Yes.                                               Yes.     3    YES
# 103        No  There is a reference to antimicrobial resistan...     2    YES
# 104       Yes                                                No.     2    YES
# 109       Yes                                               Yes.     3    YES
#
#      Unnamed: 9 PubTator
# 25          NaN       []
# 33          NaN       []
# 35          NaN       []
# 57          NaN       []
# 66          NaN       []
# 74          NaN       []
# 87          NaN       []
# 88          NaN       []
# 96          NaN       []
# 100         NaN       []
# 103         NaN       []
# 104         NaN       []
# 109         NaN       []

# %%
def pubtator_process(id):

    url = f"https://www.ncbi.nlm.nih.gov/research/pubtator3-api/publications/export/biocjson?pmids={id}&full=true"
    res = requests.get(url)
    print(id)
    res_js = json.loads(res.content)['PubTator3']

    # Only working with abstracts
    abstract_js = [js for js in res_js[0]['passages'] if js['infons']['type'] == 'abstract']

    pubt_annot = [js['annotations'] for js in abstract_js]
    pubt_annot = sum(pubt_annot, [])
    #display(pubt_annot)
    pubt_res = pubtator_generate_struct(pubt_annot)

    time.sleep(0.6)

    return sorted(pubt_res, key=lambda d: d['location']['start'])

# %%
pos_df
# Out:
#          PMC_ID      PMID                                              Title  \
# 0      101622.0  11036042  RNA polymerase inhibitors with activity agains...
# 1    10187937.0  37192172  Streptothricin F is a bactericidal antibiotic ...
# 2     1162199.0   6258580  Interaction of pseudomonic acid A with Escheri...
# 3     1251517.0  16189117  Efficacy of telavancin (TD-6424), a rapidly ba...
# 4     1482072.0  13681272                       Pharmacology of methicillin.
# ..          ...       ...                                                ...
# 106     89784.0  10722483  Pefloxacin-induced achilles tendon toxicity in...
# 107   8984893.0  35411221  Antibiotic heliomycin and its water-soluble 4-...
# 108     90866.0  11709337  Target preference of 15 quinolones against Sta...
# 109   9225766.0  35723082  Re-establishing the utility of tetracycline-cl...
# 110   9598311.0  36290043  Identification of a Small Molecule That Inhibi...
#
#                                               Abstract             T5  \
# 0    A collection of rifampin-resistant mutants of ...  <pad> yes</s>
# 1    The streptothricin natural product mixture (al...  <pad> yes</s>
# 2    Sodium pseudomonate was shown to be a powerful...  <pad> yes</s>
# 3    The efficacy of telavancin, a bactericidal lip...  <pad> yes</s>
# 4    The pharmacology of a new antibiotic methicill...  <pad> yes</s>
# ..                                                 ...            ...
# 106  Despite a relatively low incidence of serious ...   <pad> no</s>
# 107  Bladder cancer is one of the most frequent can...  <pad> yes</s>
# 108  The antibacterial activities and target inhibi...  <pad> yes</s>
# 109  The progressive increase in antibiotic resista...  <pad> yes</s>
# 110  The need for novel antibiotics has become impe...  <pad> yes</s>
#
#             Alpaca                                             LaMini Score  \
# 0              Yes                                               Yes.     3
# 1              yes  The context does not provide information on wh...   2.5
# 2             Yes.  The context describes the active inhibition an...     3
# 3              Yes                                               Yes.     3
# 4    antimicrobial                                               Yes.   2.5
# ..             ...                                                ...   ...
# 106            Yes                                                No.     1
# 107        Yes; no                                               Yes.   2.5
# 108            Yes                                                No.     2
# 109            Yes                                               Yes.     3
# 110            Yes                                                No.     2
#
#     Answer  Unnamed: 9                                           PubTator
# 0      YES         NaN  [{'text': 'rifampin', 'location': {'start': 11...
# 1      YES         NaN  [{'text': 'steptolidine', 'location': {'start'...
# 2      YES         NaN  [{'text': 'Sodium pseudomonate', 'location': {...
# 3      YES         NaN  [{'text': 'telavancin', 'location': {'start': ...
# 4      YES         NaN  [{'text': 'methicillin', 'location': {'start':...
# ..     ...         ...                                                ...
# 106     NO         NaN  [{'text': 'fluoroquinolones', 'location': {'st...
# 107    YES         NaN  [{'text': 'water', 'location': {'start': 483, ...
# 108    YES         NaN  [{'text': 'quinolones', 'location': {'start': ...
# 109    YES         NaN                                                 []
# 110    YES         NaN  [{'text': 'IMB-0042', 'location': {'start': 11...
#
# [111 rows x 11 columns]

# %%
def collapse_pubtator(row):
    texts = []
    for d in row:
        texts.append(d['text'])
    return list(set(texts))

pos_df['PubTator_simplified'] = pos_df['PubTator'].apply(collapse_pubtator)
pos_df
# Out:
#          PMC_ID      PMID                                              Title  \
# 0      101622.0  11036042  RNA polymerase inhibitors with activity agains...
# 1    10187937.0  37192172  Streptothricin F is a bactericidal antibiotic ...
# 2     1162199.0   6258580  Interaction of pseudomonic acid A with Escheri...
# 3     1251517.0  16189117  Efficacy of telavancin (TD-6424), a rapidly ba...
# 4     1482072.0  13681272                       Pharmacology of methicillin.
# ..          ...       ...                                                ...
# 106     89784.0  10722483  Pefloxacin-induced achilles tendon toxicity in...
# 107   8984893.0  35411221  Antibiotic heliomycin and its water-soluble 4-...
# 108     90866.0  11709337  Target preference of 15 quinolones against Sta...
# 109   9225766.0  35723082  Re-establishing the utility of tetracycline-cl...
# 110   9598311.0  36290043  Identification of a Small Molecule That Inhibi...
#
#                                               Abstract             T5  \
# 0    A collection of rifampin-resistant mutants of ...  <pad> yes</s>
# 1    The streptothricin natural product mixture (al...  <pad> yes</s>
# 2    Sodium pseudomonate was shown to be a powerful...  <pad> yes</s>
# 3    The efficacy of telavancin, a bactericidal lip...  <pad> yes</s>
# 4    The pharmacology of a new antibiotic methicill...  <pad> yes</s>
# ..                                                 ...            ...
# 106  Despite a relatively low incidence of serious ...   <pad> no</s>
# 107  Bladder cancer is one of the most frequent can...  <pad> yes</s>
# 108  The antibacterial activities and target inhibi...  <pad> yes</s>
# 109  The progressive increase in antibiotic resista...  <pad> yes</s>
# 110  The need for novel antibiotics has become impe...  <pad> yes</s>
#
#             Alpaca                                             LaMini Score  \
# 0              Yes                                               Yes.     3
# 1              yes  The context does not provide information on wh...   2.5
# 2             Yes.  The context describes the active inhibition an...     3
# 3              Yes                                               Yes.     3
# 4    antimicrobial                                               Yes.   2.5
# ..             ...                                                ...   ...
# 106            Yes                                                No.     1
# 107        Yes; no                                               Yes.   2.5
# 108            Yes                                                No.     2
# 109            Yes                                               Yes.     3
# 110            Yes                                                No.     2
#
#     Answer  Unnamed: 9                                           PubTator  \
# 0      YES         NaN  [{'text': 'rifampin', 'location': {'start': 11...
# 1      YES         NaN  [{'text': 'steptolidine', 'location': {'start'...
# 2      YES         NaN  [{'text': 'Sodium pseudomonate', 'location': {...
# 3      YES         NaN  [{'text': 'telavancin', 'location': {'start': ...
# 4      YES         NaN  [{'text': 'methicillin', 'location': {'start':...
# ..     ...         ...                                                ...
# 106     NO         NaN  [{'text': 'fluoroquinolones', 'location': {'st...
# 107    YES         NaN  [{'text': 'water', 'location': {'start': 483, ...
# 108    YES         NaN  [{'text': 'quinolones', 'location': {'start': ...
# 109    YES         NaN                                                 []
# 110    YES         NaN  [{'text': 'IMB-0042', 'location': {'start': 11...
#
#                                    PubTator_simplified
# 0    [corallopyronin A, streptolydigin, sorangicin ...
# 1    [guanine, streptothricin, streptothricin D, st...
# 2    [isoleucine, [14C]isoleucine, Sodium [9'-3H]ps...
# 3    [vancomycin, lipoglycopeptide, methicillin, te...
# 4    [penicillin G., penicillin G, methicillin, 6(2...
# ..                                                 ...
# 106  [radiosulfate, fluoroquinolones, Pefloxacin, N...
# 107  [4-(tert-butylamino)methyl, water, heliomycin,...
# 108  [ofloxacin, Type III quinolones, II quinolones...
# 109                                                 []
# 110                [lipopolysaccharide, LPS, IMB-0042]
#
# [111 rows x 12 columns]

# %%
pos_df.to_excel('DatasetPositivo.xlsx', columns=["PMC_ID","PMID","Title","Abstract","PubTator","PubTator_simplified"], index=False)
